# %% [markdown]
# # Retriever Custom e ParentDocumentRetriever

# %% [markdown]
# ### Creazione Vector-Store

# %%
# lettura di tutti i documenti da una cartella

from langchain_community.document_loaders import DirectoryLoader  # pip install unstructured
                                                                  # https://pypi.org/project/python-magic-bin/0.4.14/#files scaricare e installare la wheel corretta

loader = DirectoryLoader('data/dialoghi', glob="**/*.txt") # carica tutto i file .txt dalla cartella e sottocartelle
documents = loader.load()

for doc in documents:
    print(doc, "\n\n")
# Out:
# page_content='Al negozio di abbigliamento Commesso - Buongiorno, posso aiutarla? Cliente - Sì, grazie. Ho visto un paio di pantaloni neri in vetrina, posso provarli? Commesso - Certo, che taglia? Cliente - Porto una 50 Commesso - Eccoli qua! Cliente - Dove sono i camerini? Commesso - I camerini sono là in fondo a destra, accanto alle scale Cliente - Perfetto, grazie
#
# Commesso - Come vanno? Cliente - Il modello mi piace, ma sono un po' stretti. Posso provare una taglia più larga? Commesso - Oh, mi dispiace, abbiamo finito la taglia 52 in questo colore, vuole provare lo stesso modello in marrone? Cliente - No, grazie, il marrone proprio non mi piace. Non avete altri colori in questa taglia? Commesso - Allora, nella taglia 52 abbiamo il marrone, il rosso e il grigio. Cliente - Vabbè, li provo in grigio, vediamo come mi stanno.
#
# Cliente - Ho provato i pantaloni, anche in grigio sono proprio belli e la taglia è perfetta! Quanto costano? Commesso - Costano 85€ Cliente - Ma non sono in sconto? Commesso - Ah, no, mi dispiace, i saldi sono solo sulla merce invernale. Questi pantaloni sono della nuova collezione, quella estiva. Cliente - Peccato, mi sembrano un po' cari. Commesso - Guardi è cotone 100%, la qualità del materiale è eccellente! Cliente - Posso pagare con la carta di credito? Commesso - Certo, non ci sono problemi, può pagare con la carta o in contanti. Cliente - Va bene, allora li prendo, grazie mille per l’aiuto' metadata={'source': 'data/dialoghi/dialogo.txt'}
#
#
# page_content='Al supermercato Cliente 1 - Ciao, scusa, sai dove posso trovare la farina integrale? Cliente 2 - Sì, certo, dovrebbe essere nel corridoio 5, vicino agli altri prodotti da forno. Cliente 1 - Grazie mille! Sto cercando di fare una torta un po' più salutare. Cliente 2 - Ottima idea! Io invece sono qui per comprare gli ingredienti per una cena speciale. Stasera ho ospiti a casa. Cliente 1 - Che bello! Cosa hai in mente di preparare? Cliente 2 - Sto pensando a un risotto ai funghi come piatto principale. E tu, cosa stai cucinando? Cliente 1 - Una torta di mele. È la ricetta della mia nonna, ma voglio provare a renderla un po' più leggera. Cliente 2 - Sembra deliziosa! A proposito, hai provato le mele biologiche? Sono nel reparto frutta e verdura, sono davvero buone. Cliente 1 - No, non le ho mai provate. Grazie per il consiglio, andrò a prenderle!
#
# Cliente 1 - Oh, ecco il reparto frutta e verdura. Guarda quante belle zucchine! Potrei aggiungerle alla mia torta salata. Cliente 2 - Ottima idea! Le zucchine danno un tocco di freschezza. Io invece devo prendere degli spinaci freschi per il mio contorno. Cliente 1 - Adoro gli spinaci, sono così versatili. Li uso spesso nelle mie ricette. Cliente 2 - Anch'io! Ecco, prendo un paio di confezioni. Hai bisogno di altro da questo reparto? Cliente 1 - Penso di aver preso tutto. Andiamo al reparto latticini?
#
# Cliente 2 - Sì, certo. Devo prendere il burro e il formaggio per il risotto. Cliente 1 - Io invece ho bisogno di latte e yogurt. Adoro lo yogurt greco, lo uso per fare dei dolci. Cliente 2 - Anche a me piace molto. È perfetto per le colazioni sane. Oh, guarda, c'è un'offerta sul burro! Cliente 1 - Fantastico! Ne prendo un po' anche io, non si sa mai quando può servire.
#
# Cliente 2 - Prossima fermata: reparto carne. Devo prendere del pollo per il secondo piatto. Cliente 1 - Io non ho bisogno di carne oggi, ma ti accompagno. Magari trovo qualche idea per la cena di domani. Cliente 2 - Certo! Ecco, il pollo è qui. Prendo un paio di petti. Hai mai provato a fare il pollo al curry? Cliente 1 - Sì, è uno dei miei piatti preferiti. È facile e saporito. A proposito, hai già comprato il pane? Cliente 2 - No, mi stavo dimenticando. Andiamo al reparto panetteria.
#
# Cliente 1 - Guarda, hanno appena sfornato il pane integrale. Ha un profumo delizioso. Cliente 2 - Sì, sembra davvero buono. Ne prendo due filoni. Vuoi prendere qualcosa anche tu? Cliente 1 - Sì, prenderò un filone di pane integrale e qualche panino per la colazione di domani. Cliente 2 - Perfetto. Credo di aver preso tutto. E tu, hai tutto quello che ti serve? Cliente 1 - Sì, penso di sì. Andiamo alle casse?
#
# Cliente 2 - Sì, andiamo. Speriamo che non ci sia troppa fila. Cliente 1 - Guarda, quella cassa sembra abbastanza libera. Mettiamoci lì. Cliente 2 - Ottima scelta. Ecco, metto i miei articoli sul nastro. Hai trovato tutto quello che cercavi? Cliente 1 - Sì, grazie anche al tuo aiuto. È sempre un piacere fare la spesa con qualcuno. Cliente 2 - Concordo. È stato divertente e veloce. Ci vediamo alla prossima spesa! Cliente 1 - Assolutamente! A presto, buona cena! Cliente 2 - Grazie, buona torta!' metadata={'source': 'data/dialoghi/dialogo4.txt'}
#
#
# page_content='Davanti alla scuola Mamma 1 - Ciao ragazze! Come state oggi? Mamma 2 - Ciao! Bene, grazie. Solo un po' stanca, è stata una settimana lunga. E voi? Mamma 3 - Anche io sono un po' stanca. Tra lavoro e figli, non ho un attimo di pausa! Mamma 4 - Vi capisco perfettamente. Ogni tanto vorrei una giornata solo per me.
#
# Mamma 1 - Sì, sarebbe fantastico! I vostri bambini come stanno andando a scuola? Mamma 2 - Marco è un po' in difficoltà con la matematica, ma stiamo lavorando con un tutor. Speriamo migliori presto. Mamma 3 - Laura adora la matematica, invece. Ma ha qualche problema con la storia. La trova noiosa. Mamma 4 - Anche Emma. Dice che le date sono troppe da ricordare. Ma almeno va bene in italiano. Mamma 1 - Pietro è bravo in tutte le materie, ma è molto disordinato. Trova sempre difficile tenere in ordine il suo zaino e i suoi quaderni.
#
# Mamma 2 - Avete sentito della nuova maestra di inglese? Dicono che sia molto brava. Mamma 3 - Sì, mia figlia ne è entusiasta! Finalmente qualcuno che rende le lezioni interessanti. Mamma 4 - Speriamo bene. Emma ha sempre trovato difficile l'inglese. Magari con questa nuova maestra cambierà idea. Mamma 1 - Anche Pietro è contento. La maestra usa molti giochi e attività divertenti per insegnare.
#
# Mamma 2 - Qualcuna di voi sa qualcosa del prossimo incontro con i genitori? Mamma 3 - Dovrebbe essere la prossima settimana, credo. Devo ancora controllare il calendario degli eventi. Mamma 4 - Sì, è giovedì prossimo alle 17:00. Hanno detto che parleranno dei progressi dei bambini e dei prossimi progetti scolastici. Mamma 1 - Perfetto, così posso organizzarmi. Ho bisogno di sapere se ci sarà bisogno di qualche contributo da parte nostra.
#
# Mamma 2 - A proposito di progetti, avete sentito del nuovo laboratorio di scienze? Mamma 3 - Sì! Laura non vede l'ora di partecipare. Finalmente qualcosa di pratico! Mamma 4 - Emma è entusiasta all'idea di fare esperimenti. Dice che vuole diventare una scienziata. Mamma 1 - Anche Pietro è molto interessato. Spero solo che non facciano troppi pasticci!
#
# Mamma 2 - Cambiando argomento, cosa farete questo fine settimana? Mamma 3 - Noi andiamo al parco, sperando che il tempo sia bello. I bambini hanno bisogno di correre un po'. Mamma 4 - Noi invece visiteremo i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1 - Noi pensavamo di andare al cinema. C'è un nuovo film per bambini che sembra carino. Mamma 2 - Buone idee! Anche noi potremmo fare un'escursione in montagna. I bambini adorano esplorare.
#
# Mamma 3 - E i vostri mariti? Come si stanno organizzando con i bambini? Mamma 4 - Mio marito è molto impegnato con il lavoro, ma cerchiamo di trovare sempre del tempo da passare insieme nel fine settimana. Mamma 1 - Il mio cerca di aiutare il più possibile, anche se a volte sembra più un altro bambino da gestire! Mamma 2 - Il mio è molto coinvolto. Si occupa spesso dei compiti dei bambini, soprattutto in materie che io non capisco! Mamma 3 - Il mio è simile. Fa il possibile per essere presente. Siamo fortunate ad avere mariti collaborativi.
#
# Mamma 4 - Guardate, stanno uscendo! Finalmente! Mamma 1 - Sì, è ora di andare. Ci vediamo domani! Mamma 2 - A domani, ciao a tutte! Mamma 3 - Ciao, buona giornata! Mamma 4 - Ciao, buona serata!' metadata={'source': 'data/dialoghi/dialogo3.txt'}
#
#
# page_content='In palestra
#
# Atleta 1 - Ehi, ciao! Come va?
#
# Atleta 2 - Ciao! Tutto bene, grazie. Sto cercando di migliorare la mia resistenza. Hai qualche consiglio?
#
# Atleta 1 - Certo! Quanto tempo dedichi al cardio?
#
# Atleta 2 - Di solito faccio 30 minuti di corsa, tre volte a settimana.
#
# Atleta 1 - Bene, potresti provare ad aumentare gradualmente il tempo. Magari aggiungi 5 minuti ogni settimana.
#
# Atleta 2 - Buona idea! E per la dieta, cosa mi consigli?
#
# Atleta 1 - È importante mangiare in modo equilibrato. Assicurati di avere una buona quantità di proteine e carboidrati complessi.
#
# Atleta 2 - Grazie del consiglio! Hai qualche esercizio specifico per migliorare la resistenza muscolare?
#
# Atleta 1 - Sì, prova a fare circuiti di allenamento ad alta intensità. Combinano esercizi di forza e cardio, sono ottimi per la resistenza.
#
# Atleta 2 - Interessante, li proverò! E tu, su cosa stai lavorando adesso?
#
# Atleta 1 - Sto cercando di aumentare la massa muscolare. Mi sto concentrando molto sugli allenamenti con i pesi.
#
# Atleta 2 - Hai un programma specifico che segui?
#
# Atleta 1 - Sì, faccio un allenamento suddiviso per gruppi muscolari: petto e tricipiti un giorno, schiena e bicipiti un altro, e gambe e spalle un altro ancora.
#
# Atleta 2 - Sembra un buon piano! Hai notato miglioramenti?
#
# Atleta 1 - Sì, sto vedendo dei progressi. L'importante è essere costanti e avere pazienza.
#
# Atleta 2 - Grazie per i consigli! Ci vediamo in giro!
#
# Atleta 1 - Prego, buona fortuna con il tuo allenamento! A presto!' metadata={'source': 'data/dialoghi/dialogo2.txt'}
#
#
# page_content='In ufficio, durante la pausa caffè Impiegato 1 - Ciao a tutti! Finalmente un po' di pausa. Come va? Impiegato 2 - Ciao! Tutto bene, grazie. Oggi è una giornata piuttosto intensa. E tu? Impiegato 3 - Anche io sto correndo da una riunione all'altra. Non vedo l'ora che arrivi il weekend. Impiegato 4 - Già, questa settimana sembra non finire mai. Avete sentito delle nuove direttive del capo?
#
# Impiegato 1 - Sì, le ho lette stamattina. Sembra che ci saranno dei cambiamenti importanti nei prossimi mesi. Impiegato 2 - Esatto. Soprattutto per quanto riguarda il lavoro da remoto. Vogliono ridurre le giornate a casa. Impiegato 3 - Davvero? A me il lavoro da casa piaceva. È molto più comodo. Impiegato 4 - Anche a me. Però capisco che vogliano più persone in ufficio. Si lavora meglio in team.
#
# Impiegato 1 - È vero. E poi, così possiamo fare più pause caffè insieme! Impiegato 2 - Ah ah, hai ragione! A proposito di caffè, avete provato la nuova macchina? Fa un espresso ottimo. Impiegato 3 - Sì, l'ho provata ieri. È molto meglio della vecchia. Finalmente un caffè decente! Impiegato 4 - Anche io la trovo fantastica. Almeno qualcosa di positivo in questa settimana.
#
# Impiegato 1 - A parte il caffè, come vanno i vostri progetti? Io sono sommerso di lavoro. Impiegato 2 - Il mio progetto procede bene, ma ci sono sempre delle complicazioni dell'ultimo minuto. E tu? Impiegato 3 - Sto lavorando a una nuova presentazione per i clienti. È quasi pronta, ma devo ancora rifinirla. Impiegato 4 - Io invece sto cercando di rispettare tutte le scadenze. È una corsa contro il tempo.
#
# Impiegato 1 - Capisco. A volte sembra che non ci siano abbastanza ore nella giornata. Ma almeno siamo tutti sulla stessa barca. Impiegato 2 - Già, è bello sapere che non siamo soli. E poi, possiamo sempre contare sull'aiuto dei colleghi. Impiegato 3 - Esatto. E le nostre pause caffè sono un ottimo modo per ricaricarci e scambiare due chiacchiere. Impiegato 4 - Sì, queste pause sono indispensabili. A proposito, qualcuno ha piani per il weekend?
#
# Impiegato 1 - Io penso di andare al mare, se il tempo regge. Ho bisogno di un po' di relax. Impiegato 2 - Bella idea! Io invece farò un'escursione in montagna. Mi piace stare all'aria aperta. Impiegato 3 - Io passerò il weekend in città. C'è una nuova mostra d'arte che voglio visitare. Impiegato 4 - Interessante! Io invece ho intenzione di rilassarmi a casa. Magari guardare qualche film o leggere un buon libro.
#
# Impiegato 1 - Suona come un piano perfetto. Qualunque cosa facciate, spero che vi rilassiate e vi divertiate. Impiegato 2 - Sicuramente! Abbiamo tutti bisogno di una pausa. Ah, guardate l'orologio. È quasi ora di tornare al lavoro. Impiegato 3 - Già, il tempo vola quando ci si diverte. Torniamo alle nostre scrivanie. Impiegato 4 - Buon lavoro a tutti! E ricordate, un'altra pausa caffè tra un paio d'ore? Impiegato 1 - Assolutamente! A dopo! Impiegato 2 - Ci conto! A dopo! Impiegato 3 - A dopo, ciao! Impiegato 4 - A dopo, buon lavoro!' metadata={'source': 'data/dialoghi/dialogo5.txt'}

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

vectorstore = Chroma.from_documents(documents=documents, embedding=OpenAIEmbeddings())

# %%
for doc in vectorstore.similarity_search("mamma", k=1):
    print(doc.metadata["source"], doc.page_content[:50] + "...\n\n")
# Out:
# data/dialoghi/dialogo3.txt Davanti alla scuola Mamma 1 - Ciao ragazze! Come s...

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 1})
res = retriever.invoke("mamme che parlano")
res
# Out:
# [Document(id='ad460a98-c140-4c17-9471-86dabdd7fc99', metadata={'source': 'data/dialoghi/dialogo3.txt'}, page_content="Davanti alla scuola Mamma 1 - Ciao ragazze! Come state oggi? Mamma 2 - Ciao! Bene, grazie. Solo un po' stanca, è stata una settimana lunga. E voi? Mamma 3 - Anche io sono un po' stanca. Tra lavoro e figli, non ho un attimo di pausa! Mamma 4 - Vi capisco perfettamente. Ogni tanto vorrei una giornata solo per me.\n\nMamma 1 - Sì, sarebbe fantastico! I vostri bambini come stanno andando a scuola? Mamma 2 - Marco è un po' in difficoltà con la matematica, ma stiamo lavorando con un tutor. Speriamo migliori presto. Mamma 3 - Laura adora la matematica, invece. Ma ha qualche problema con la storia. La trova noiosa. Mamma 4 - Anche Emma. Dice che le date sono troppe da ricordare. Ma almeno va bene in italiano. Mamma 1 - Pietro è bravo in tutte le materie, ma è molto disordinato. Trova sempre difficile tenere in ordine il suo zaino e i suoi quaderni.\n\nMamma 2 - Avete sentito della nuova maestra di inglese? Dicono che sia molto brava. Mamma 3 - Sì, mia figlia ne è entusiasta! Finalmente qualcuno che rende le lezioni interessanti. Mamma 4 - Speriamo bene. Emma ha sempre trovato difficile l'inglese. Magari con questa nuova maestra cambierà idea. Mamma 1 - Anche Pietro è contento. La maestra usa molti giochi e attività divertenti per insegnare.\n\nMamma 2 - Qualcuna di voi sa qualcosa del prossimo incontro con i genitori? Mamma 3 - Dovrebbe essere la prossima settimana, credo. Devo ancora controllare il calendario degli eventi. Mamma 4 - Sì, è giovedì prossimo alle 17:00. Hanno detto che parleranno dei progressi dei bambini e dei prossimi progetti scolastici. Mamma 1 - Perfetto, così posso organizzarmi. Ho bisogno di sapere se ci sarà bisogno di qualche contributo da parte nostra.\n\nMamma 2 - A proposito di progetti, avete sentito del nuovo laboratorio di scienze? Mamma 3 - Sì! Laura non vede l'ora di partecipare. Finalmente qualcosa di pratico! Mamma 4 - Emma è entusiasta all'idea di fare esperimenti. Dice che vuole diventare una scienziata. Mamma 1 - Anche Pietro è molto interessato. Spero solo che non facciano troppi pasticci!\n\nMamma 2 - Cambiando argomento, cosa farete questo fine settimana? Mamma 3 - Noi andiamo al parco, sperando che il tempo sia bello. I bambini hanno bisogno di correre un po'. Mamma 4 - Noi invece visiteremo i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1 - Noi pensavamo di andare al cinema. C'è un nuovo film per bambini che sembra carino. Mamma 2 - Buone idee! Anche noi potremmo fare un'escursione in montagna. I bambini adorano esplorare.\n\nMamma 3 - E i vostri mariti? Come si stanno organizzando con i bambini? Mamma 4 - Mio marito è molto impegnato con il lavoro, ma cerchiamo di trovare sempre del tempo da passare insieme nel fine settimana. Mamma 1 - Il mio cerca di aiutare il più possibile, anche se a volte sembra più un altro bambino da gestire! Mamma 2 - Il mio è molto coinvolto. Si occupa spesso dei compiti dei bambini, soprattutto in materie che io non capisco! Mamma 3 - Il mio è simile. Fa il possibile per essere presente. Siamo fortunate ad avere mariti collaborativi.\n\nMamma 4 - Guardate, stanno uscendo! Finalmente! Mamma 1 - Sì, è ora di andare. Ci vediamo domani! Mamma 2 - A domani, ciao a tutte! Mamma 3 - Ciao, buona giornata! Mamma 4 - Ciao, buona serata!")]

# %% [markdown]
# # Retriever Custom
# ### tramite decoratore *chain*
#
# Spesso è utile creare retriever custom per poter inserire ulteriori informazioni oltre a quelle direttamente fornite dal VectorStore.

# %%
query="mamme che parlano"
vectorstore.similarity_search_with_score(query)
# Out:
# [(Document(id='ad460a98-c140-4c17-9471-86dabdd7fc99', metadata={'source': 'data/dialoghi/dialogo3.txt'}, page_content="Davanti alla scuola Mamma 1 - Ciao ragazze! Come state oggi? Mamma 2 - Ciao! Bene, grazie. Solo un po' stanca, è stata una settimana lunga. E voi? Mamma 3 - Anche io sono un po' stanca. Tra lavoro e figli, non ho un attimo di pausa! Mamma 4 - Vi capisco perfettamente. Ogni tanto vorrei una giornata solo per me.\n\nMamma 1 - Sì, sarebbe fantastico! I vostri bambini come stanno andando a scuola? Mamma 2 - Marco è un po' in difficoltà con la matematica, ma stiamo lavorando con un tutor. Speriamo migliori presto. Mamma 3 - Laura adora la matematica, invece. Ma ha qualche problema con la storia. La trova noiosa. Mamma 4 - Anche Emma. Dice che le date sono troppe da ricordare. Ma almeno va bene in italiano. Mamma 1 - Pietro è bravo in tutte le materie, ma è molto disordinato. Trova sempre difficile tenere in ordine il suo zaino e i suoi quaderni.\n\nMamma 2 - Avete sentito della nuova maestra di inglese? Dicono che sia molto brava. Mamma 3 - Sì, mia figlia ne è entusiasta! Finalmente qualcuno che rende le lezioni interessanti. Mamma 4 - Speriamo bene. Emma ha sempre trovato difficile l'inglese. Magari con questa nuova maestra cambierà idea. Mamma 1 - Anche Pietro è contento. La maestra usa molti giochi e attività divertenti per insegnare.\n\nMamma 2 - Qualcuna di voi sa qualcosa del prossimo incontro con i genitori? Mamma 3 - Dovrebbe essere la prossima settimana, credo. Devo ancora controllare il calendario degli eventi. Mamma 4 - Sì, è giovedì prossimo alle 17:00. Hanno detto che parleranno dei progressi dei bambini e dei prossimi progetti scolastici. Mamma 1 - Perfetto, così posso organizzarmi. Ho bisogno di sapere se ci sarà bisogno di qualche contributo da parte nostra.\n\nMamma 2 - A proposito di progetti, avete sentito del nuovo laboratorio di scienze? Mamma 3 - Sì! Laura non vede l'ora di partecipare. Finalmente qualcosa di pratico! Mamma 4 - Emma è entusiasta all'idea di fare esperimenti. Dice che vuole diventare una scienziata. Mamma 1 - Anche Pietro è molto interessato. Spero solo che non facciano troppi pasticci!\n\nMamma 2 - Cambiando argomento, cosa farete questo fine settimana? Mamma 3 - Noi andiamo al parco, sperando che il tempo sia bello. I bambini hanno bisogno di correre un po'. Mamma 4 - Noi invece visiteremo i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1 - Noi pensavamo di andare al cinema. C'è un nuovo film per bambini che sembra carino. Mamma 2 - Buone idee! Anche noi potremmo fare un'escursione in montagna. I bambini adorano esplorare.\n\nMamma 3 - E i vostri mariti? Come si stanno organizzando con i bambini? Mamma 4 - Mio marito è molto impegnato con il lavoro, ma cerchiamo di trovare sempre del tempo da passare insieme nel fine settimana. Mamma 1 - Il mio cerca di aiutare il più possibile, anche se a volte sembra più un altro bambino da gestire! Mamma 2 - Il mio è molto coinvolto. Si occupa spesso dei compiti dei bambini, soprattutto in materie che io non capisco! Mamma 3 - Il mio è simile. Fa il possibile per essere presente. Siamo fortunate ad avere mariti collaborativi.\n\nMamma 4 - Guardate, stanno uscendo! Finalmente! Mamma 1 - Sì, è ora di andare. Ci vediamo domani! Mamma 2 - A domani, ciao a tutte! Mamma 3 - Ciao, buona giornata! Mamma 4 - Ciao, buona serata!"),
#   0.32034605741500854),
#  (Document(id='ec64ae56-8e8e-4221-bb58-4146e84c5261', metadata={'source': 'data/dialoghi/dialogo4.txt'}, page_content="Al supermercato Cliente 1 - Ciao, scusa, sai dove posso trovare la farina integrale? Cliente 2 - Sì, certo, dovrebbe essere nel corridoio 5, vicino agli altri prodotti da forno. Cliente 1 - Grazie mille! Sto cercando di fare una torta un po' più salutare. Cliente 2 - Ottima idea! Io invece sono qui per comprare gli ingredienti per una cena speciale. Stasera ho ospiti a casa. Cliente 1 - Che bello! Cosa hai in mente di preparare? Cliente 2 - Sto pensando a un risotto ai funghi come piatto principale. E tu, cosa stai cucinando? Cliente 1 - Una torta di mele. È la ricetta della mia nonna, ma voglio provare a renderla un po' più leggera. Cliente 2 - Sembra deliziosa! A proposito, hai provato le mele biologiche? Sono nel reparto frutta e verdura, sono davvero buone. Cliente 1 - No, non le ho mai provate. Grazie per il consiglio, andrò a prenderle!\n\nCliente 1 - Oh, ecco il reparto frutta e verdura. Guarda quante belle zucchine! Potrei aggiungerle alla mia torta salata. Cliente 2 - Ottima idea! Le zucchine danno un tocco di freschezza. Io invece devo prendere degli spinaci freschi per il mio contorno. Cliente 1 - Adoro gli spinaci, sono così versatili. Li uso spesso nelle mie ricette. Cliente 2 - Anch'io! Ecco, prendo un paio di confezioni. Hai bisogno di altro da questo reparto? Cliente 1 - Penso di aver preso tutto. Andiamo al reparto latticini?\n\nCliente 2 - Sì, certo. Devo prendere il burro e il formaggio per il risotto. Cliente 1 - Io invece ho bisogno di latte e yogurt. Adoro lo yogurt greco, lo uso per fare dei dolci. Cliente 2 - Anche a me piace molto. È perfetto per le colazioni sane. Oh, guarda, c'è un'offerta sul burro! Cliente 1 - Fantastico! Ne prendo un po' anche io, non si sa mai quando può servire.\n\nCliente 2 - Prossima fermata: reparto carne. Devo prendere del pollo per il secondo piatto. Cliente 1 - Io non ho bisogno di carne oggi, ma ti accompagno. Magari trovo qualche idea per la cena di domani. Cliente 2 - Certo! Ecco, il pollo è qui. Prendo un paio di petti. Hai mai provato a fare il pollo al curry? Cliente 1 - Sì, è uno dei miei piatti preferiti. È facile e saporito. A proposito, hai già comprato il pane? Cliente 2 - No, mi stavo dimenticando. Andiamo al reparto panetteria.\n\nCliente 1 - Guarda, hanno appena sfornato il pane integrale. Ha un profumo delizioso. Cliente 2 - Sì, sembra davvero buono. Ne prendo due filoni. Vuoi prendere qualcosa anche tu? Cliente 1 - Sì, prenderò un filone di pane integrale e qualche panino per la colazione di domani. Cliente 2 - Perfetto. Credo di aver preso tutto. E tu, hai tutto quello che ti serve? Cliente 1 - Sì, penso di sì. Andiamo alle casse?\n\nCliente 2 - Sì, andiamo. Speriamo che non ci sia troppa fila. Cliente 1 - Guarda, quella cassa sembra abbastanza libera. Mettiamoci lì. Cliente 2 - Ottima scelta. Ecco, metto i miei articoli sul nastro. Hai trovato tutto quello che cercavi? Cliente 1 - Sì, grazie anche al tuo aiuto. È sempre un piacere fare la spesa con qualcuno. Cliente 2 - Concordo. È stato divertente e veloce. Ci vediamo alla prossima spesa! Cliente 1 - Assolutamente! A presto, buona cena! Cliente 2 - Grazie, buona torta!"),
#   0.444622665643692),
#  (Document(id='266d7186-b999-4922-9b1f-5bd21fc7d50b', metadata={'source': 'data/dialoghi/dialogo5.txt'}, page_content="In ufficio, durante la pausa caffè Impiegato 1 - Ciao a tutti! Finalmente un po' di pausa. Come va? Impiegato 2 - Ciao! Tutto bene, grazie. Oggi è una giornata piuttosto intensa. E tu? Impiegato 3 - Anche io sto correndo da una riunione all'altra. Non vedo l'ora che arrivi il weekend. Impiegato 4 - Già, questa settimana sembra non finire mai. Avete sentito delle nuove direttive del capo?\n\nImpiegato 1 - Sì, le ho lette stamattina. Sembra che ci saranno dei cambiamenti importanti nei prossimi mesi. Impiegato 2 - Esatto. Soprattutto per quanto riguarda il lavoro da remoto. Vogliono ridurre le giornate a casa. Impiegato 3 - Davvero? A me il lavoro da casa piaceva. È molto più comodo. Impiegato 4 - Anche a me. Però capisco che vogliano più persone in ufficio. Si lavora meglio in team.\n\nImpiegato 1 - È vero. E poi, così possiamo fare più pause caffè insieme! Impiegato 2 - Ah ah, hai ragione! A proposito di caffè, avete provato la nuova macchina? Fa un espresso ottimo. Impiegato 3 - Sì, l'ho provata ieri. È molto meglio della vecchia. Finalmente un caffè decente! Impiegato 4 - Anche io la trovo fantastica. Almeno qualcosa di positivo in questa settimana.\n\nImpiegato 1 - A parte il caffè, come vanno i vostri progetti? Io sono sommerso di lavoro. Impiegato 2 - Il mio progetto procede bene, ma ci sono sempre delle complicazioni dell'ultimo minuto. E tu? Impiegato 3 - Sto lavorando a una nuova presentazione per i clienti. È quasi pronta, ma devo ancora rifinirla. Impiegato 4 - Io invece sto cercando di rispettare tutte le scadenze. È una corsa contro il tempo.\n\nImpiegato 1 - Capisco. A volte sembra che non ci siano abbastanza ore nella giornata. Ma almeno siamo tutti sulla stessa barca. Impiegato 2 - Già, è bello sapere che non siamo soli. E poi, possiamo sempre contare sull'aiuto dei colleghi. Impiegato 3 - Esatto. E le nostre pause caffè sono un ottimo modo per ricaricarci e scambiare due chiacchiere. Impiegato 4 - Sì, queste pause sono indispensabili. A proposito, qualcuno ha piani per il weekend?\n\nImpiegato 1 - Io penso di andare al mare, se il tempo regge. Ho bisogno di un po' di relax. Impiegato 2 - Bella idea! Io invece farò un'escursione in montagna. Mi piace stare all'aria aperta. Impiegato 3 - Io passerò il weekend in città. C'è una nuova mostra d'arte che voglio visitare. Impiegato 4 - Interessante! Io invece ho intenzione di rilassarmi a casa. Magari guardare qualche film o leggere un buon libro.\n\nImpiegato 1 - Suona come un piano perfetto. Qualunque cosa facciate, spero che vi rilassiate e vi divertiate. Impiegato 2 - Sicuramente! Abbiamo tutti bisogno di una pausa. Ah, guardate l'orologio. È quasi ora di tornare al lavoro. Impiegato 3 - Già, il tempo vola quando ci si diverte. Torniamo alle nostre scrivanie. Impiegato 4 - Buon lavoro a tutti! E ricordate, un'altra pausa caffè tra un paio d'ore? Impiegato 1 - Assolutamente! A dopo! Impiegato 2 - Ci conto! A dopo! Impiegato 3 - A dopo, ciao! Impiegato 4 - A dopo, buon lavoro!"),
#   0.44506949186325073),
#  (Document(id='900417cf-79f6-4717-a3d1-53d1ebd82bb6', metadata={'source': 'data/dialoghi/dialogo.txt'}, page_content="Al negozio di abbigliamento Commesso - Buongiorno, posso aiutarla? Cliente - Sì, grazie. Ho visto un paio di pantaloni neri in vetrina, posso provarli? Commesso - Certo, che taglia? Cliente - Porto una 50 Commesso - Eccoli qua! Cliente - Dove sono i camerini? Commesso - I camerini sono là in fondo a destra, accanto alle scale Cliente - Perfetto, grazie\n\nCommesso - Come vanno? Cliente - Il modello mi piace, ma sono un po' stretti. Posso provare una taglia più larga? Commesso - Oh, mi dispiace, abbiamo finito la taglia 52 in questo colore, vuole provare lo stesso modello in marrone? Cliente - No, grazie, il marrone proprio non mi piace. Non avete altri colori in questa taglia? Commesso - Allora, nella taglia 52 abbiamo il marrone, il rosso e il grigio. Cliente - Vabbè, li provo in grigio, vediamo come mi stanno.\n\nCliente - Ho provato i pantaloni, anche in grigio sono proprio belli e la taglia è perfetta! Quanto costano? Commesso - Costano 85€ Cliente - Ma non sono in sconto? Commesso - Ah, no, mi dispiace, i saldi sono solo sulla merce invernale. Questi pantaloni sono della nuova collezione, quella estiva. Cliente - Peccato, mi sembrano un po' cari. Commesso - Guardi è cotone 100%, la qualità del materiale è eccellente! Cliente - Posso pagare con la carta di credito? Commesso - Certo, non ci sono problemi, può pagare con la carta o in contanti. Cliente - Va bene, allora li prendo, grazie mille per l’aiuto"),
#   0.46766114234924316)]

# %%
from typing import List
from langchain_core.documents import Document
from langchain_core.runnables import chain

# Grazie al decoratore @chain possiamo creare un runnable custom.
# Implementando un runnable che prende in input una query e restituisce una lista di Document
# a conti fatto abbiamo creato un retriever custom che, a questo punto, possiamo custimizzare come vogliamo.
#
# In questo caso, ci limitiamo a restituire i documenti con lo score di similarità che abbiamo ottenuto 
# tramite similarity_search_with_score (che restituisce una lista di tuple (Document, score)), inserito nei metadati
@chain
def retriever(query: str) -> List[Document]:
    results = vectorstore.similarity_search_with_score(query)
    for doc, score in results:
        doc.metadata["score"] = score
    return [doc for doc, _ in results]

res = retriever.invoke("mamme che parlano")

for r in res:
    print(r.page_content.replace("\n", "")[:25], "\t", r.metadata)
# Out:
# Davanti alla scuola Mamma 	 {'source': 'data/dialoghi/dialogo3.txt', 'score': 0.32034605741500854}
# Al supermercato Cliente 1 	 {'source': 'data/dialoghi/dialogo4.txt', 'score': 0.444622665643692}
# In ufficio, durante la pa 	 {'source': 'data/dialoghi/dialogo5.txt', 'score': 0.44506949186325073}
# Al negozio di abbigliamen 	 {'source': 'data/dialoghi/dialogo.txt', 'score': 0.46766114234924316}

# %%
res
# Out:
# [Document(id='ad460a98-c140-4c17-9471-86dabdd7fc99', metadata={'source': 'data/dialoghi/dialogo3.txt', 'score': 0.32034605741500854}, page_content="Davanti alla scuola Mamma 1 - Ciao ragazze! Come state oggi? Mamma 2 - Ciao! Bene, grazie. Solo un po' stanca, è stata una settimana lunga. E voi? Mamma 3 - Anche io sono un po' stanca. Tra lavoro e figli, non ho un attimo di pausa! Mamma 4 - Vi capisco perfettamente. Ogni tanto vorrei una giornata solo per me.\n\nMamma 1 - Sì, sarebbe fantastico! I vostri bambini come stanno andando a scuola? Mamma 2 - Marco è un po' in difficoltà con la matematica, ma stiamo lavorando con un tutor. Speriamo migliori presto. Mamma 3 - Laura adora la matematica, invece. Ma ha qualche problema con la storia. La trova noiosa. Mamma 4 - Anche Emma. Dice che le date sono troppe da ricordare. Ma almeno va bene in italiano. Mamma 1 - Pietro è bravo in tutte le materie, ma è molto disordinato. Trova sempre difficile tenere in ordine il suo zaino e i suoi quaderni.\n\nMamma 2 - Avete sentito della nuova maestra di inglese? Dicono che sia molto brava. Mamma 3 - Sì, mia figlia ne è entusiasta! Finalmente qualcuno che rende le lezioni interessanti. Mamma 4 - Speriamo bene. Emma ha sempre trovato difficile l'inglese. Magari con questa nuova maestra cambierà idea. Mamma 1 - Anche Pietro è contento. La maestra usa molti giochi e attività divertenti per insegnare.\n\nMamma 2 - Qualcuna di voi sa qualcosa del prossimo incontro con i genitori? Mamma 3 - Dovrebbe essere la prossima settimana, credo. Devo ancora controllare il calendario degli eventi. Mamma 4 - Sì, è giovedì prossimo alle 17:00. Hanno detto che parleranno dei progressi dei bambini e dei prossimi progetti scolastici. Mamma 1 - Perfetto, così posso organizzarmi. Ho bisogno di sapere se ci sarà bisogno di qualche contributo da parte nostra.\n\nMamma 2 - A proposito di progetti, avete sentito del nuovo laboratorio di scienze? Mamma 3 - Sì! Laura non vede l'ora di partecipare. Finalmente qualcosa di pratico! Mamma 4 - Emma è entusiasta all'idea di fare esperimenti. Dice che vuole diventare una scienziata. Mamma 1 - Anche Pietro è molto interessato. Spero solo che non facciano troppi pasticci!\n\nMamma 2 - Cambiando argomento, cosa farete questo fine settimana? Mamma 3 - Noi andiamo al parco, sperando che il tempo sia bello. I bambini hanno bisogno di correre un po'. Mamma 4 - Noi invece visiteremo i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1 - Noi pensavamo di andare al cinema. C'è un nuovo film per bambini che sembra carino. Mamma 2 - Buone idee! Anche noi potremmo fare un'escursione in montagna. I bambini adorano esplorare.\n\nMamma 3 - E i vostri mariti? Come si stanno organizzando con i bambini? Mamma 4 - Mio marito è molto impegnato con il lavoro, ma cerchiamo di trovare sempre del tempo da passare insieme nel fine settimana. Mamma 1 - Il mio cerca di aiutare il più possibile, anche se a volte sembra più un altro bambino da gestire! Mamma 2 - Il mio è molto coinvolto. Si occupa spesso dei compiti dei bambini, soprattutto in materie che io non capisco! Mamma 3 - Il mio è simile. Fa il possibile per essere presente. Siamo fortunate ad avere mariti collaborativi.\n\nMamma 4 - Guardate, stanno uscendo! Finalmente! Mamma 1 - Sì, è ora di andare. Ci vediamo domani! Mamma 2 - A domani, ciao a tutte! Mamma 3 - Ciao, buona giornata! Mamma 4 - Ciao, buona serata!"),
#  Document(id='ec64ae56-8e8e-4221-bb58-4146e84c5261', metadata={'source': 'data/dialoghi/dialogo4.txt', 'score': 0.444622665643692}, page_content="Al supermercato Cliente 1 - Ciao, scusa, sai dove posso trovare la farina integrale? Cliente 2 - Sì, certo, dovrebbe essere nel corridoio 5, vicino agli altri prodotti da forno. Cliente 1 - Grazie mille! Sto cercando di fare una torta un po' più salutare. Cliente 2 - Ottima idea! Io invece sono qui per comprare gli ingredienti per una cena speciale. Stasera ho ospiti a casa. Cliente 1 - Che bello! Cosa hai in mente di preparare? Cliente 2 - Sto pensando a un risotto ai funghi come piatto principale. E tu, cosa stai cucinando? Cliente 1 - Una torta di mele. È la ricetta della mia nonna, ma voglio provare a renderla un po' più leggera. Cliente 2 - Sembra deliziosa! A proposito, hai provato le mele biologiche? Sono nel reparto frutta e verdura, sono davvero buone. Cliente 1 - No, non le ho mai provate. Grazie per il consiglio, andrò a prenderle!\n\nCliente 1 - Oh, ecco il reparto frutta e verdura. Guarda quante belle zucchine! Potrei aggiungerle alla mia torta salata. Cliente 2 - Ottima idea! Le zucchine danno un tocco di freschezza. Io invece devo prendere degli spinaci freschi per il mio contorno. Cliente 1 - Adoro gli spinaci, sono così versatili. Li uso spesso nelle mie ricette. Cliente 2 - Anch'io! Ecco, prendo un paio di confezioni. Hai bisogno di altro da questo reparto? Cliente 1 - Penso di aver preso tutto. Andiamo al reparto latticini?\n\nCliente 2 - Sì, certo. Devo prendere il burro e il formaggio per il risotto. Cliente 1 - Io invece ho bisogno di latte e yogurt. Adoro lo yogurt greco, lo uso per fare dei dolci. Cliente 2 - Anche a me piace molto. È perfetto per le colazioni sane. Oh, guarda, c'è un'offerta sul burro! Cliente 1 - Fantastico! Ne prendo un po' anche io, non si sa mai quando può servire.\n\nCliente 2 - Prossima fermata: reparto carne. Devo prendere del pollo per il secondo piatto. Cliente 1 - Io non ho bisogno di carne oggi, ma ti accompagno. Magari trovo qualche idea per la cena di domani. Cliente 2 - Certo! Ecco, il pollo è qui. Prendo un paio di petti. Hai mai provato a fare il pollo al curry? Cliente 1 - Sì, è uno dei miei piatti preferiti. È facile e saporito. A proposito, hai già comprato il pane? Cliente 2 - No, mi stavo dimenticando. Andiamo al reparto panetteria.\n\nCliente 1 - Guarda, hanno appena sfornato il pane integrale. Ha un profumo delizioso. Cliente 2 - Sì, sembra davvero buono. Ne prendo due filoni. Vuoi prendere qualcosa anche tu? Cliente 1 - Sì, prenderò un filone di pane integrale e qualche panino per la colazione di domani. Cliente 2 - Perfetto. Credo di aver preso tutto. E tu, hai tutto quello che ti serve? Cliente 1 - Sì, penso di sì. Andiamo alle casse?\n\nCliente 2 - Sì, andiamo. Speriamo che non ci sia troppa fila. Cliente 1 - Guarda, quella cassa sembra abbastanza libera. Mettiamoci lì. Cliente 2 - Ottima scelta. Ecco, metto i miei articoli sul nastro. Hai trovato tutto quello che cercavi? Cliente 1 - Sì, grazie anche al tuo aiuto. È sempre un piacere fare la spesa con qualcuno. Cliente 2 - Concordo. È stato divertente e veloce. Ci vediamo alla prossima spesa! Cliente 1 - Assolutamente! A presto, buona cena! Cliente 2 - Grazie, buona torta!"),
#  Document(id='266d7186-b999-4922-9b1f-5bd21fc7d50b', metadata={'source': 'data/dialoghi/dialogo5.txt', 'score': 0.44506949186325073}, page_content="In ufficio, durante la pausa caffè Impiegato 1 - Ciao a tutti! Finalmente un po' di pausa. Come va? Impiegato 2 - Ciao! Tutto bene, grazie. Oggi è una giornata piuttosto intensa. E tu? Impiegato 3 - Anche io sto correndo da una riunione all'altra. Non vedo l'ora che arrivi il weekend. Impiegato 4 - Già, questa settimana sembra non finire mai. Avete sentito delle nuove direttive del capo?\n\nImpiegato 1 - Sì, le ho lette stamattina. Sembra che ci saranno dei cambiamenti importanti nei prossimi mesi. Impiegato 2 - Esatto. Soprattutto per quanto riguarda il lavoro da remoto. Vogliono ridurre le giornate a casa. Impiegato 3 - Davvero? A me il lavoro da casa piaceva. È molto più comodo. Impiegato 4 - Anche a me. Però capisco che vogliano più persone in ufficio. Si lavora meglio in team.\n\nImpiegato 1 - È vero. E poi, così possiamo fare più pause caffè insieme! Impiegato 2 - Ah ah, hai ragione! A proposito di caffè, avete provato la nuova macchina? Fa un espresso ottimo. Impiegato 3 - Sì, l'ho provata ieri. È molto meglio della vecchia. Finalmente un caffè decente! Impiegato 4 - Anche io la trovo fantastica. Almeno qualcosa di positivo in questa settimana.\n\nImpiegato 1 - A parte il caffè, come vanno i vostri progetti? Io sono sommerso di lavoro. Impiegato 2 - Il mio progetto procede bene, ma ci sono sempre delle complicazioni dell'ultimo minuto. E tu? Impiegato 3 - Sto lavorando a una nuova presentazione per i clienti. È quasi pronta, ma devo ancora rifinirla. Impiegato 4 - Io invece sto cercando di rispettare tutte le scadenze. È una corsa contro il tempo.\n\nImpiegato 1 - Capisco. A volte sembra che non ci siano abbastanza ore nella giornata. Ma almeno siamo tutti sulla stessa barca. Impiegato 2 - Già, è bello sapere che non siamo soli. E poi, possiamo sempre contare sull'aiuto dei colleghi. Impiegato 3 - Esatto. E le nostre pause caffè sono un ottimo modo per ricaricarci e scambiare due chiacchiere. Impiegato 4 - Sì, queste pause sono indispensabili. A proposito, qualcuno ha piani per il weekend?\n\nImpiegato 1 - Io penso di andare al mare, se il tempo regge. Ho bisogno di un po' di relax. Impiegato 2 - Bella idea! Io invece farò un'escursione in montagna. Mi piace stare all'aria aperta. Impiegato 3 - Io passerò il weekend in città. C'è una nuova mostra d'arte che voglio visitare. Impiegato 4 - Interessante! Io invece ho intenzione di rilassarmi a casa. Magari guardare qualche film o leggere un buon libro.\n\nImpiegato 1 - Suona come un piano perfetto. Qualunque cosa facciate, spero che vi rilassiate e vi divertiate. Impiegato 2 - Sicuramente! Abbiamo tutti bisogno di una pausa. Ah, guardate l'orologio. È quasi ora di tornare al lavoro. Impiegato 3 - Già, il tempo vola quando ci si diverte. Torniamo alle nostre scrivanie. Impiegato 4 - Buon lavoro a tutti! E ricordate, un'altra pausa caffè tra un paio d'ore? Impiegato 1 - Assolutamente! A dopo! Impiegato 2 - Ci conto! A dopo! Impiegato 3 - A dopo, ciao! Impiegato 4 - A dopo, buon lavoro!"),
#  Document(id='900417cf-79f6-4717-a3d1-53d1ebd82bb6', metadata={'source': 'data/dialoghi/dialogo.txt', 'score': 0.46766114234924316}, page_content="Al negozio di abbigliamento Commesso - Buongiorno, posso aiutarla? Cliente - Sì, grazie. Ho visto un paio di pantaloni neri in vetrina, posso provarli? Commesso - Certo, che taglia? Cliente - Porto una 50 Commesso - Eccoli qua! Cliente - Dove sono i camerini? Commesso - I camerini sono là in fondo a destra, accanto alle scale Cliente - Perfetto, grazie\n\nCommesso - Come vanno? Cliente - Il modello mi piace, ma sono un po' stretti. Posso provare una taglia più larga? Commesso - Oh, mi dispiace, abbiamo finito la taglia 52 in questo colore, vuole provare lo stesso modello in marrone? Cliente - No, grazie, il marrone proprio non mi piace. Non avete altri colori in questa taglia? Commesso - Allora, nella taglia 52 abbiamo il marrone, il rosso e il grigio. Cliente - Vabbè, li provo in grigio, vediamo come mi stanno.\n\nCliente - Ho provato i pantaloni, anche in grigio sono proprio belli e la taglia è perfetta! Quanto costano? Commesso - Costano 85€ Cliente - Ma non sono in sconto? Commesso - Ah, no, mi dispiace, i saldi sono solo sulla merce invernale. Questi pantaloni sono della nuova collezione, quella estiva. Cliente - Peccato, mi sembrano un po' cari. Commesso - Guardi è cotone 100%, la qualità del materiale è eccellente! Cliente - Posso pagare con la carta di credito? Commesso - Certo, non ci sono problemi, può pagare con la carta o in contanti. Cliente - Va bene, allora li prendo, grazie mille per l’aiuto")]

# %% [markdown]
# # ParentDocumentRetriever
# ### Recupero di un Chunk e del Documento che lo contiene
#
# Il ParentDocumentRetriever è un retriever che ci permette di utilizzare i chunk per le ricerche ma ci restituisce poi, non il chunk stesso, ma l'intero documento da cui quel chunk è stato estratto. In questo modo la ricerca è fatta su un vettore "piccolo" (il chunk) ma ci portiamo poi all'interno del prompt, non il chunk piccola, ma l'informazione completa che il modello può utilizzare per generare la risposta
#
# In pratica, embeddizziamo e ricerchiamo chunk, ma poi restituiamo documenti interi

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.storage import InMemoryStore
from langchain.retrievers import ParentDocumentRetriever

child_splitter = RecursiveCharacterTextSplitter(chunk_size=400) # creiamo i chunk di 400 caratteri

vectorstore = Chroma(collection_name="full_documents", embedding_function=OpenAIEmbeddings())

store = InMemoryStore() # in questo modo lo storage avviene in memoria non persistente

retriever = ParentDocumentRetriever(
    vectorstore=vectorstore, 
    docstore=store, 
    child_splitter=child_splitter, 
)

# i documenti vengono chunkizzati e aggiunti al vectorstore
# mentre i documenti interi vengono aggiunti al docstore
retriever.add_documents(documents, ids=None)  

list(store.yield_keys())
# Out:
# ['50448847-8296-483c-bc28-f3f84795098c',
#  '183f0303-ae78-41bc-b156-e8861e8420c5',
#  '065ec3a3-8be4-4ade-8a34-ff0a576eaf78',
#  '431afd4f-fb3f-410e-8581-583b1f83037f',
#  'aaf13234-fcb4-4dcd-83bd-73ea01f0e4b5']

# %%
# Nello store abbiamo solo i documenti interi
len(list(store.yield_keys()))
# Out:
# 5

# %% [markdown]
# La query eseguita sul vector store, mi restituisce i chunk più simili

# %%
sub_docs = vectorstore.similarity_search("mamme che parlano")
print(sub_docs[0].page_content)
print("===")
print(len(sub_docs[0].page_content))
# Out:
# Mamma 1 - Sì, sarebbe fantastico! I vostri bambini come stanno andando a scuola? Mamma 2 - Marco è un po' in difficoltà con la matematica, ma stiamo lavorando con un tutor. Speriamo migliori presto. Mamma 3 - Laura adora la matematica, invece. Ma ha qualche problema con la storia. La trova noiosa. Mamma 4 - Anche Emma. Dice che le date sono troppe da ricordare. Ma almeno va bene in italiano.
# ===
# 394

# %% [markdown]
# Mentre, la stessa query eseguita sul retriever mi restituisce il documento intero

# %%
retrieved_docs = retriever.invoke("mamme che parlano")
print(retrieved_docs[0].page_content)
print("===")
print(len(retrieved_docs[0].page_content))
# Out:
# Davanti alla scuola Mamma 1 - Ciao ragazze! Come state oggi? Mamma 2 - Ciao! Bene, grazie. Solo un po' stanca, è stata una settimana lunga. E voi? Mamma 3 - Anche io sono un po' stanca. Tra lavoro e figli, non ho un attimo di pausa! Mamma 4 - Vi capisco perfettamente. Ogni tanto vorrei una giornata solo per me.
#
# Mamma 1 - Sì, sarebbe fantastico! I vostri bambini come stanno andando a scuola? Mamma 2 - Marco è un po' in difficoltà con la matematica, ma stiamo lavorando con un tutor. Speriamo migliori presto. Mamma 3 - Laura adora la matematica, invece. Ma ha qualche problema con la storia. La trova noiosa. Mamma 4 - Anche Emma. Dice che le date sono troppe da ricordare. Ma almeno va bene in italiano. Mamma 1 - Pietro è bravo in tutte le materie, ma è molto disordinato. Trova sempre difficile tenere in ordine il suo zaino e i suoi quaderni.
#
# Mamma 2 - Avete sentito della nuova maestra di inglese? Dicono che sia molto brava. Mamma 3 - Sì, mia figlia ne è entusiasta! Finalmente qualcuno che rende le lezioni interessanti. Mamma 4 - Speriamo bene. Emma ha sempre trovato difficile l'inglese. Magari con questa nuova maestra cambierà idea. Mamma 1 - Anche Pietro è contento. La maestra usa molti giochi e attività divertenti per insegnare.
#
# Mamma 2 - Qualcuna di voi sa qualcosa del prossimo incontro con i genitori? Mamma 3 - Dovrebbe essere la prossima settimana, credo. Devo ancora controllare il calendario degli eventi. Mamma 4 - Sì, è giovedì prossimo alle 17:00. Hanno detto che parleranno dei progressi dei bambini e dei prossimi progetti scolastici. Mamma 1 - Perfetto, così posso organizzarmi. Ho bisogno di sapere se ci sarà bisogno di qualche contributo da parte nostra.
#
# Mamma 2 - A proposito di progetti, avete sentito del nuovo laboratorio di scienze? Mamma 3 - Sì! Laura non vede l'ora di partecipare. Finalmente qualcosa di pratico! Mamma 4 - Emma è entusiasta all'idea di fare esperimenti. Dice che vuole diventare una scienziata. Mamma 1 - Anche Pietro è molto interessato. Spero solo che non facciano troppi pasticci!
#
# Mamma 2 - Cambiando argomento, cosa farete questo fine settimana? Mamma 3 - Noi andiamo al parco, sperando che il tempo sia bello. I bambini hanno bisogno di correre un po'. Mamma 4 - Noi invece visiteremo i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1 - Noi pensavamo di andare al cinema. C'è un nuovo film per bambini che sembra carino. Mamma 2 - Buone idee! Anche noi potremmo fare un'escursione in montagna. I bambini adorano esplorare.
#
# Mamma 3 - E i vostri mariti? Come si stanno organizzando con i bambini? Mamma 4 - Mio marito è molto impegnato con il lavoro, ma cerchiamo di trovare sempre del tempo da passare insieme nel fine settimana. Mamma 1 - Il mio cerca di aiutare il più possibile, anche se a volte sembra più un altro bambino da gestire! Mamma 2 - Il mio è molto coinvolto. Si occupa spesso dei compiti dei bambini, soprattutto in materie che io non capisco! Mamma 3 - Il mio è simile. Fa il possibile per essere presente. Siamo fortunate ad avere mariti collaborativi.
#
# Mamma 4 - Guardate, stanno uscendo! Finalmente! Mamma 1 - Sì, è ora di andare. Ci vediamo domani! Mamma 2 - A domani, ciao a tutte! Mamma 3 - Ciao, buona giornata! Mamma 4 - Ciao, buona serata!
# ===
# 3268

# %% [markdown]
# ## Gestione di Chunk multi-livello
#
# In alcuni casi però, recuperare l'intero documento da cui il chunk è stato creato, rischia di farci recurare documenti eccessivamente grandi che non potrebbero poi essere utilizzati all'interno del prompt.
#
# Per gestire questo problema possiamo usare dei chunk multi-livello. L'idea di base è quella di *recuperare piccole parti di un chunk, per poi recuperare il chunk da cui sono state generate.*

# %%
# Text-Splitter per i chunk di documento più grandi, da usare come dati recuperati
parent_splitter = RecursiveCharacterTextSplitter(chunk_size=350, chunk_overlap=150)

# Secondo Text-Splitter, per la creazione di chunk più piccoli su cui inidicizzare le ricerche
child_splitter = RecursiveCharacterTextSplitter(chunk_size=85, chunk_overlap=15)

vectorstore = Chroma(collection_name="split_parents", embedding_function=OpenAIEmbeddings())

# dizionario in memoria utilizzato per recuperare i documenti più grandi, una volta
# identificati tramite ricerca sui chunk più piccoli
store = InMemoryStore()

# %%
# ParentDocumentRetriever gestisce automaticamente
# il "doppio livello" di granularità dei chunk

retriever = ParentDocumentRetriever(
    vectorstore=vectorstore,
    docstore=store,
    child_splitter=child_splitter,
    parent_splitter=parent_splitter,
)

# i documenti vengono splittati in chunk più grandi (parent) e poi in chunk più piccoli (child)
# i chunk più piccoli vengono indicizzati nel vectorstore, mentre i chunk più grandi
# vengono memorizzati nel docstore
retriever.add_documents(documents)

# Rispetto a prima, adesso nello store abbiamo molti più documenti
# perché prima avevamo solo i documenti interi, mentre adesso
# abbiamo i chunk più grandi (parent). Ovviamente nel vectorstore
# abbiamo molti più chunk
len(list(store.yield_keys()))
# Out:
# 57

# %%
# accedendo al VectrorStore (Chroma), tramite similarity search, la ricerca viene effettuata
# sui chunk estratti più piccoli
sub_docs = vectorstore.similarity_search("mamme che parlano")

print(sub_docs[0].page_content)
print("===")
print(len(sub_docs[0].page_content))
# Out:
# i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1
# ===
# 83

# %%
# il retriever ritorna invece il chunk di documento più grande
retrieved_docs = retriever.invoke("mamme che parlano")

print(retrieved_docs[0].page_content)
print("===")
print(len(retrieved_docs[0].page_content))
# Out:
# Mamma 2 - Cambiando argomento, cosa farete questo fine settimana? Mamma 3 - Noi andiamo al parco, sperando che il tempo sia bello. I bambini hanno bisogno di correre un po'. Mamma 4 - Noi invece visiteremo i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1 - Noi pensavamo di andare al cinema. C'è un nuovo film per
# ===
# 348

# %%
for r in retrieved_docs:
    print(r)
# Out:
# page_content='Mamma 2 - Cambiando argomento, cosa farete questo fine settimana? Mamma 3 - Noi andiamo al parco, sperando che il tempo sia bello. I bambini hanno bisogno di correre un po'. Mamma 4 - Noi invece visiteremo i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1 - Noi pensavamo di andare al cinema. C'è un nuovo film per' metadata={'source': 'data/dialoghi/dialogo3.txt'}
# page_content='i nonni. È da un po' che non li vediamo e i bambini ne sentono la mancanza. Mamma 1 - Noi pensavamo di andare al cinema. C'è un nuovo film per bambini che sembra carino. Mamma 2 - Buone idee! Anche noi potremmo fare un'escursione in montagna. I bambini adorano esplorare.' metadata={'source': 'data/dialoghi/dialogo3.txt'}
# page_content='Mamma 2 - Avete sentito della nuova maestra di inglese? Dicono che sia molto brava. Mamma 3 - Sì, mia figlia ne è entusiasta! Finalmente qualcuno che rende le lezioni interessanti. Mamma 4 - Speriamo bene. Emma ha sempre trovato difficile l'inglese. Magari con questa nuova maestra cambierà idea. Mamma 1 - Anche Pietro è contento. La maestra usa' metadata={'source': 'data/dialoghi/dialogo3.txt'}
