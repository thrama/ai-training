# %% [markdown]
# # Question Answering su pagine web

# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader

bs4_strainer = bs4.SoupStrainer()
loader = WebBaseLoader(
    web_paths=(
        "https://datamasters.it/corsi/",
        "https://datamasters.it/corsi/generative-ai/",
        "https://datamasters.it/corsi/machine-learning-per-tutti/",
        "https://datamasters.it/corsi/data-driven-mindset/",
        "https://datamasters.it/corsi/python-from-zero-to-hero/",
        "https://datamasters.it/corsi/ai-prompt-engineering/",
        "https://datamasters.it/corsi/corsi-data-scientist/",
        "https://datamasters.it/corsi/algotrading-in-python/",
        "https://corsi.datamasters.it/offers/8vpgpbtd/checkout",
        "https://datamasters.it/corsi/matematica-statistica-per-machine-learning/",
        "https://datamasters.it/corsi/machine-learning-starter-kit/",
        "https://datamasters.it/corsi/data-scientist-starter-kit/",
        "https://datamasters.it/corsi/machine-learning-foundations/"
    ),
    bs_kwargs={"parse_only": bs4_strainer},
)
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'https://datamasters.it/corsi/', 'title': 'Catalogo dei Corsi sullâ€™AI - Data Masters', 'description': "Esplora il nostro catalogo e scopri i migliori corsi di formazione continua, sempre aggiornati e con un forte taglio pratico nel campo della Data Science, del Machine Learning e dell'Intelligenza Artificiale.", 'language': 'it-IT'}, page_content='\n\nCatalogo dei Corsi sullâ€™AI - Data Masters\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nIMPARA A CREARE AGENTI AIÂ\xa0 Â\xa0PROMO 50% FINO AL 31 LUGLIO\nScopri di piÃ¹DataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediMigliora le competenze su dati e AI.\nOttieni la tua certificazione\nScopri qual Ã¨ il giusto corso per te\nFai ora il testApplica filtri PERCORSO DI CARRIERAMachine Learning EngineerIl Percorso di Carriera piÃ¹ completo e aggiornato per acquisire le competenze professionali piÃ¹ avanzate in Machine Learning, Deep Learning e Reinforcement Learning che ti permetteranno di risolvere problemi reali e sviluppare soluzioni custom in ambito aziendale.Un modello didattico unico che prevede una live a settimana dopo gli orari lavorativi.DURATA TOTALE:4 mesi circaLIVELLO:AvanzatoPREREQUISITO:PythonPROGETTI:12 project workLIVE:1 live a settimanaSTIPENDIO MEDIO:35K - 75K+Scopri di piÃ¹Cosa impareraiCORSONUOVO CORSOChatGPT: il corso completoPorta realmente lâ€™AI nel tuo lavoro e nella tua azienda, utilizzando tutte le funzionalitÃ\xa0 di ChatGPT in modo professionale. Impara passo dopo passo come sfruttare i nuovi strumenti avanzati su casi dâ€™uso reali.DURATA TOTALE:7 oreLIVELLO:PrincipiantePREREQUISITO:Nessun prerequisitoScopri di piÃ¹CORSONUOVO CORSODAX Avanzato10 ore di formazione intensiva per dominare le funzionalitÃ\xa0 piÃ¹ avanzate di DAX (Data Analysis Expressions) e portare le tue analisi con Power BI a un livello superiore.DURATA TOTALE:10 OreLIVELLO:IntermedioPREREQUISITO:Power BIScopri di piÃ¹CORSONUOVO CORSOAI Act: Governance, Rischi e Implementazione dell\'AI in AziendaLa Guida completa e aggiornata al nuovo Regolamento Europeo sull\'intelligenza artificiale, spiegato da uno degli autori dell\'AI Act.DURATA TOTALE:8 OreLIVELLO:IntermedioLIVE:4 Sessioni Live con i docentiScopri di piÃ¹CORSONUOVO CORSOExcel per Analisi DatiExcel Ã¨ il pilastro dellâ€™analisi dati in ambito aziendale e padroneggiarlo Ã¨ una competenza imprescindibile. In questo corso, progettato dai nostri professionisti dei dati, diventerai un esperto di Excel in Data Analytics e imparerai a gestire, analizzare e visualizzare dati con lo strumento piÃ¹ utilizzato in ogni azienda.DURATA TOTALE:14 OreLIVELLO:PrincipiantePREREQUISITO:NessunoScopri di piÃ¹CORSOIntelligenza Artificiale per TuttiIl corso non tecnico progettato per aiutare i dipendenti di tutte le aziende a comprendere meglio l\'intelligenza artificiale.Â\xa0DURATA TOTALE:14 oreLIVELLO:PrincipiantePREREQUISITO:nessunoScopri di piÃ¹CORSOReinforcement LearningPotenzia la tua expertise di Deep Learning: scopri il potenziale del Reinforcement Learning con Gymnasium, padroneggia algoritmi avanzati come A3C e DQN, e costruisci soluzioni AI allâ€™avanguardiaDURATA TOTALE:5 oreLIVELLO:AvanzatoPREREQUISITO:Python, Reti Ricorrenti, Reti Convolutive, Deep LearningScopri di piÃ¹CORSOCORSO GRATUITOMachine Learning per TuttiEsplorare il Machine Learning senza pre-requisiti tecnici: un corso che permette a tutti di avvicinarsi a queste discipline in modo semplice ed accessibile.DURATA TOTALE:1 oraLIVELLO:PrincipiantePREREQUISITO:NessunoScopri di piÃ¹CORSOT ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/generative-ai/', 'title': 'Corso di AI Generativa | Data Masters', 'description': 'Tutti gli strumenti di Generative Ai più usati al mondo in un unico corso. 15 ore di formazione completa sulla AI generativa. Entra ora in Data Masters!', 'language': 'it-IT'}, page_content="\n\nCorso di AI Generativa | Data Masters\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediCorso di\nGenerative AI\nAumenta la produttività del tuo lavoro grazie all’AI Generativa\nIl corso Generative AI é stato creato per essere la tua guida nella scoperta del potenziale illimitato delle Generative AI.\nAccedi ad aggiornamenti mensili, approfondimenti\xa0e lezioni con docenti sempre nuove. Tutto quello che ti serve per restare al passo con i nuovi trend di mercato in un unico corso. Alcuni degli strumenti che imparerai ad utilizzare:\n\nChatGPT\nClaude\nCopilot\nMidjourney\nCanva\nTutti i migliori tool al mondo\n\n237€397€FINO AL 31 LUGLIO40%SCONTO\n\nLA PROMO SCADE TRA:\n\n06GIORNI06ORE28MINUTI37SECONDIAccesso a tutte le video lezioniAccesso a tutte le lezioni mensili in diretta con i docentiAggiornamenti mensili inclusiEsercitazioni su PROGETTI REALICertificazione finale Supporto docentiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nLEZIONI REGISTRATE42 ore di video lezioni sempre disponibiliLEZIONI LIVE2 lezioni mensili in diretta con i docentiUPDATEAggiornamenti futuri inclusiSUPPORTO DOCENTIH24 inclusoGARANZIASoddisfatti o rimborsatiL’evoluzione dell’AI è rapidissima, non restare indietro!\nCon il corso GENERATIVE AI imparerai ad utilizzare al meglio tutti i principali strumenti di Generative AI per aumentare la produttività nel tuo lavoro anche senza competenze tecniche. Un corso che risponde alle esigenze di tutti i professionisti che vogliono utilizzare in modo pratico l’Intelligenza Artificiale.\nFormiamo i professionisti delle migliori aziende al mondo\n\n\nTrustpilot\n\nCosa può fare la\nGenerative AI per il tuo lavoro\nGenera contenuti su misura per marketing e social media\nCon ChatGPT, Canva e Firefly puoi creare testi, immagini e grafiche accattivanti e mirate per le tue campagne marketing. Automatizza la creazione di contenuti per i tuoi post sui social media, blog e newsletter, aumentando l’efficacia e risparmiando tempo. \nSTRUMENTI AI :ChatGPT, Canva, Firefly, Gemini, ClaudeAnalizza i tuoi dati e crea report in pochi secondi\nCon la potenza di ChatGPT e Copilot, puoi caricare e analizzare grandi quantità di dati in pochi istanti, creando report dettagliati e approfonditi senza doverli scrivere manualmente. Scopri come ottenere insight rapidi e precisi che possono guidare le tue decisioni aziendali. \nSTRUMENTI AI :ChatGPT, Copilot, Gemini, ClaudeCrea immagini e video personalizzati\nTrasforma idee in contenuti visivi sorprendenti con strumenti come DALL-E, Midjourney e Heygen. Personalizza immagini e video per presentazioni, social media e pubblicità, dando vita alla tua visione creativa senza necessità di competenze tecniche avanzate. \nSTRUMENTI AI :DALL-E, Midjourney, HeygenAccedi a conoscenze specialistiche in qualsiasi settore\nGrazie a ChatGPT, puoi dialogare con l’intelligenza artificiale e ricevere risposte specializzate in qualsiasi ambito professionale. Dal marketing alla tecnologia, fino al diritto o alla finanza, ottieni informazioni rapide, accurate e aggiornate. \nSTRUMENTI AI :ChatGPT, Gemini, ClaudeGestione documentale con la Generative AI: automazion ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/machine-learning-per-tutti/', 'title': 'Machine Learning per tutti | Corsi Data Masters', 'description': 'Esplora il Machine Learning senza pre-requisiti tecnici: un corso che permette a tutti di avvicinarsi al mondo ML e AI', 'language': 'it-IT'}, page_content="\n\nMachine Learning per tutti | Corsi Data Masters\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccedimachine learning per tutti\nEsplora il machine learning in modo semplice e accessibile, anche senza competenze tecniche. In questo corso imparerai tutte le nozioni che ti permetteranno rapidamente di iniziare ad orientarti nel settore. \nIl modo migliore per iniziare questo viaggio affascinante all’interno della tecnologia che sta cambiando il mondo e sulla quale non è più possibile restare indietro.\nINIZIA ORA27€GRATISImpara ad orientarti nel mondo del MLAccesso alla community su DISCORDAccesso alla dashboard di Data MastersENTRA ORADURATA TOTALE1 ora di formazione avanzataLEZIONI6 Video-lezioni online sempre disponibiliSUPPORTO DOCENTIH24 inclusoEntra nel mondo dell’AI e del Machine Learning partendo da zero\nQuesto corso è appositamente progettato per coloro che desiderano esplorare il mondo del machine learning senza dover padroneggiare complesse competenze tecniche. Vengono trasferiti i principali concetti del Machine Learning, tra cui le basi teoriche e pratiche, le applicazioni e l’importanza dei dati di qualità. \nEsplorerai anche la distinzione tra intelligenza artificiale, machine learning e deep learning, e approfondirai il ruolo dell’interazione umana nel successo dei progetti di machine learning. Inoltre, acquisirai competenze sulla classificazione degli algoritmi di machine learning utilizzati per l’analisi e la modellazione dei dati.\nIntroduzione al Machine Learning\nEsploreremo le caratteristiche, le potenzialità ed i limiti del machine learning, illustrando i principali algoritmi e applicazioni e mostrando come si può impiegare per risolvere problemi realiAnalisi descrittiva, predittiva e prescrittiva\nTre approcci fondamentali nell’ambito dell’analisi dei dati. Ciascun approccio ha una sua specifica finalità e utilità, e possono essere utilizzati in molte applicazioni realiL’importanza della\nqualità dei dati\nIl machine learning non può garantire la qualità dei risultati se i dati usati per l’apprendimento sono scarsi, incompleti, sbilanciati o inaccuratiOverfitting\nFenomeno che si verifica quando un modello statistico o di machine learning si adatta troppo ai dati di addestramentoInterpretabilità del Machine Learning\nL’interpretabilità può avere diversi livelli e forme, a seconda del tipo di modello, del dominio applicativo e degli obiettivi ma è sicuramente una caratteristica desiderabile nel machine learningComponente umana\nIl machine learning e l’intelligenza umana hanno caratteristiche e abilità diverse, non in competizione tra loro, ma complementari e che si devono integrareParadigmi di Machine Learning\nI paradigmi principali dell’apprendimento automatico e le macro classi che racchiudono e definiscono tutti gli algoritmi di machine learningMetriche per valutazione e confronto\nAspetto fondamentale quando parliamo di machine learning, ovvero il concetto di metrica o di misura delle performance di un modelloPreviousNextPROGRAMMA\nIntroduzione al ML\nIntroduzione al Corso\nIntroduzione al Machine Learning\nProcesso di Implementazione\nNo Free Lunch Theorem\nRegressione Lineare\nSG ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/data-driven-mindset/', 'title': 'Corso Intelligenza Artificiale per tutti', 'description': "INTELLIGENZA ARTIFICIALE PER TUTTI è un corso non tecnico progettato per aiutare i dipendenti di tutte le aziende a comprendere meglio l'intelligenza artificiale.", 'language': 'it-IT'}, page_content="\n\nCorso Intelligenza Artificiale per tutti\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nIMPARA A CREARE AGENTI AI\xa0 \xa0PROMO 50% FINO AL 31 LUGLIO\nScopri di piùDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediCORSO\nIntelligenza artificiale per tutti\nIl primo passo per competere nell’era dell’AI.\nUna guida completa alla creazione e gestione del lavoro basate sull’intelligenza artificiale.\nINTELLIGENZA ARTIFICIALE PER TUTTI è un corso non tecnico progettato per aiutare i dipendenti di tutte le aziende a comprendere meglio l’intelligenza artificiale.\xa0 Il corso permetterà a tutti di individuare opportunità per applicare AI nel proprio lavoro, risolvere problemi aziendali in modo sicuro e pratico. Il corso comprende una guida completa che ti aiuterà a capire:\n\nI concetti fondamentali di base per affrontare il cambiamento tecnologico in atto\nL’impatto dell’Intelligenza Artificiale sulla società e sul tuo lavoro\nCome utilizzare i principali strumenti di Generative AI come ChatGPT, Copilot e altri.\nCome creare una strategia di utilizzo dell’intelligenza artificiale\n\n199€\nCON CERTIFICAZIONE FINALE\n\nAccesso a tutte le video lezioniEsercitazioni su PROGETTI REALISupporto docentiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nSTUDIA QUANDO VUOI80 Video-lezioni online sempre disponibiliDURATA TOTALE14 ore di formazione avanzataSUPPORTO DOCENTIH24 inclusoCERTIFICAZIONEDa aggiungere al CV e al profilo LinkedinGARANZIASoddisfatti o rimborsatiScopri come l’AI trasformerà il tuo lavoro\nUn percorso pratico e accessibile per guidarti passo dopo passo nell’uso degli strumenti che stanno rivoluzionando il modo di lavorare.\xa0\nFormiamo i professionisti delle migliori aziende al mondo\n\n\nTrustpilot\n\nPerché l’AI è fondamentale per il tuo lavoro\nNon si tratta più di essere all’avanguardia, ma di non rimanere indietro. L’AI sta rivoluzionando ogni aspetto del lavoro: dal modo in cui prendiamo decisioni alla gestione di progetti e risorse, dalla velocità di risoluzione dei problemi alla qualità del lavoro quotidiano. Chi oggi comprende e sa utilizzare l’AI acquisisce un vantaggio professionale concreto, diventa più efficiente e produttivo, si prepara per i ruoli più richiesti in futuro e può guidare attivamente il cambiamento nella propria azienda: un’opportunità che non puoi permetterti di ignorare.\nL'AI è già realtà aziendaleIl 72% delle aziende ha già integrato l'AI nei propri processi. Non è più una tecnologia del futuro, ma uno strumento essenziale che sta trasformando il modo di lavorare di migliaia di professionisti in questo momento.Raddoppia la tua produttivitàLe analisi dimostrano che i professionisti che utilizzano strumenti di AI completano le stesse attività in metà tempo. Questo significa non solo maggiore efficienza, ma anche più spazio per attività strategiche e creative.Fai carriera con l'AIL'85% dei dirigenti considera le competenze in AI un fattore determinante per le promozioni. In un mercato iper competitivo, l'AI è diventata una competenza imprescindibile per far crescere la propria carriera.La formazione è la priorità3 aziende su 4 stanno investendo nella formazione AI del proprio perso ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/python-from-zero-to-hero/', 'title': 'Corso di Python per chi inizia da zero | Data Masters', 'description': 'Impara a programmare nel linguaggio più richiesto al mondo in 15 ore: Python from Zero to Hero è il corso COMPLETO per beginners.', 'language': 'it-IT'}, page_content='\n\nCorso di Python per chi inizia da zero | Data Masters\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediPython from Zero to Hero\nIl Corso di Python che inizia dalle basi\nImpara a programmare in Python da Zero, il corso è progettato per concentrare il massimo valore nel più breve tempo possibile.\n97€\nCON CERTIFICAZIONE FINALE\n\nNessun prerequisito15 ore di formazione avanzataEsercitazioni su PROGETTI REALIAccesso per sempreSupporto docentiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nDURATA TOTALE15 ore di formazione avanzataLEZIONI28 video lezioni online sempre disponibiliSUPPORTO DOCENTIH24 inclusoCERTIFICAZIONEDa aggiungere al CV e al profilo LinkedinGARANZIASoddisfatti o rimborsatiPython è il linguaggio più potente per lavorare con i dati\nIn questo corso, partendo da zero, imparerai rapidamente a programmare acquisendo le skill\xa0per entrare nel mondo Data e AI.\nTuttE le skill per entrare\nnel mondo data e ai\nFondamenti PythonSetup Ambiente PythonVariabili e Tipi DatoControllo di FlussoFunzioni e Strutture DatiGestione StringheAritmetica Floating PointGestione FileMutabilityList ComprehensionSerializzazione JSON e PickleOOP e EreditarietàEccezioni PythonProgrammazione ReteClusteringSviluppo BotAPIPROGRAMMA\nFondamenti di Python\nIntroduzione a Python\nInstallazione di Python\nInstallazione di python e configurazione dei virtualenv su Mac OS\nGestione dei Site Packages con Pip e Virtualenv\nEspressioni e Variabili\nControlli di Flusso: booleani e if/else\nLoop: Cicli For\nLoop: Cicli While\nStrutture Dati: Liste\nStrutture Dati: Tuple\nStrutture Dati: Dictionary\nStrutture Dati: Set\nRappresentazione dei Dati: Charset ed Encoding\nStringhe, Encoding e Decoding\nRappresentazione dei Dati: lo standard IEEE 754 e i numeri reali\nAritmetica Floating Point in Python\nFunzioni\nGestione dei File\nMutability in Python\nList Comprehension in Python\nSerializzazione dei Dati: i Moduli Json e Pickle Parte 1\nSerializzazione dei Dati: i Moduli Json e Pickle Parte 2\nCenni sul Protocollo  HTTP\nIl Modulo Requests per Interazioni HTTP\nIntroduzione alla Programmazione ad Oggetti\nEreditarietà\nDunder Methods nella Programmazione ad Oggetti\nAttributi Privati e Name Mangling\nCenni sulle Eccezioni\nEsercitazione Gaming: Sasso Carta Forbice – Traccia\nEsercitazione Gaming: Sasso Carta Forbice  – Implementazione\nEsercitazione Gaming: Impiccato – Traccia\nEsercitazione Gaming: Impiccato – Implementazione\nEsercitazione ASCII Art – Traccia\nEsercitazione ASCII Art – Implementazione\nEsercitazione – Rest API in Python con Apifootball.com\nEsercitazione – Implementazione di un Algoritmo di Clustering su Dataset Pokemon\nEsercitazione Gaming: Wordle\nEsercitazione Creazione di un Bot Discord\nIl percorso per diventare Data Scientist\n\nMaggiori informazioniACQUISTA ORA7 Esercitazioni\nHero-Level\nMetti subito alla prova le nuove skill nelle esercitazioni guidate del corso\ne impara ad usare Python in diverse applicazioni.\n\xa0\nESERCITAZIONE\nCrea un Bot DISCORD in Python\nImpara a creare un bot discord capace di rispondere a semplici comandi degli utenti dei server sui quali il bot è p ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/ai-prompt-engineering/', 'title': 'AI Prompt Engineering | Corsi Data Masters', 'description': 'AI Prompt Engineering è il corso avanzato per imparare a dialogare in modo efficiente e scientifico con i Large Language Models grazie alla Generative AI.', 'language': 'it-IT'}, page_content="\n\nAI Prompt Engineering | Corsi Data Masters\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediAI PROMPT  ENGINEERING\nIl corso di Prompt Engineering per interrogare e padroneggiare tutti gli strumenti di Generative AI.\nAI Prompt Engineering è una guida avanzata per creare prompt efficaci per interagire con i modelli di linguaggio (LLMs) e sfruttare\nal massimo la potenza della Generative AI.\n49€\nCON CERTIFICAZIONE FINALE\n\n4 ore di formazione avanzataNessun prerequisitoGuida PRATICA al Prompt EngineeringAccesso per sempreSupporto docentiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nDURATA TOTALE4 ore di formazione avanzataLEZIONI23 Video-lezioni online sempre disponibiliSUPPORTO DOCENTIH24 inclusoCERTIFICAZIONEDa aggiungere al CV e al profilo LinkedinGARANZIASoddisfatti o rimborsatiDiventa un esperto di Prompt Engineering\nPer sfruttare a pieno il potenziale della Generative AI è fondamentale comprendere la logica del prompt engineering e come dirigere la tecnologia verso un output ottimale. Scopri come padroneggiare le tecniche avanzate per migliorare l’efficacia dei modelli di linguaggio avanzati e ottenere risultati precisi e rilevanti.\nTutte le skill necessarie per diventare esperto in ai prompt engineering\nPrompt EngineeringAdvanced Prompt EngineeringPillole di LLM sfrutta tutta la potenza di\nChat-GPT e dei Large Language Models\nACQUISTA ORAPROGRAMMA\nPrompt Engineering\nIntroduzione\nCos’è un Prompt\nFormulazione di un prompt\nTipologie di prompt\nTipologie di task\nScelta della tipologia di prompt\nGuida pratica alla Strutturazione di Prompt Efficaci\nConclusioni\n\nMaggiori informazioniAdvancend Prompt Engineering\nIntroduzione\nTecniche Avanzate\nValutare un Modello\nPiattaforme per il Prompting\n\nMaggiori informazioniPillole di LLM\nIntroduzione ai LLM (Large Language Models)\nGeneralità sugli LLM\nTokenizzazione\nEmbeddings\nProcesso di Apprendimento\nArchitetture GPT\nSplit Learning\nDistillation\nHallucination\nSfide & Use Cases Attuali\nArchitetture a Confronto\n\nMaggiori informazioniACQUISTA ORAVuoi parlare direttamente\ncon chi ha già seguito questo corso?\nEntra nella community per avere un feedback diretto dagli studenti.\nInoltre, ti aspettano tantissime opportunità di networking, crescita e live di approfondimento.\n\nConfrontati con i membri della community e\xa0Impara dai migliori\nApprofondisci e aggiorna costantemente le tue competenze\nAccedi a progetti di gruppo e data challenge\n\nOttieni la certificazione e aggiungila alla tua formazione su LinkedIn\nAl termine del corso riceverai una certificazione di completamento che attesta le ore di formazione svolte e le nuove competenze acquisite. Aggiungendola sul CV e LinkedIn potenzierai immediatamente il tuo profilo con una delle skill più richieste dalle aziende.\nDOVE LAVORANO\nI NOSTRI STUDENTI\nGLI STUDENTI DICONO DI NOI\nEccellente4.9 \xa0|\xa0 230 recensioniConsidero la mia esperienza relativa al…Considero la mia esperienza relativa al corso “AI Prompt Engeneering” ottima e straordinaria. Il corso è spiegato in maniera semplice, chiara ed efficace, lo consiglio vivamente.Alessandro ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters', 'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT'}, page_content="\n\nML Engineer con la Machine Learning Masterclass | Data Masters\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nULTIMI TICKET SCONTATI 40% – START NUOVA CLASSE SETTEMBRE\nRICHIEDI INFORMAZIONIDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccedi\xa0Start nuova classe Settembre\nDiventa ML Engineer\ncon la Machine Learning Masterclass\nIl Percorso di Carriera più completo e aggiornato per acquisire le competenze professionali più avanzate in Machine Learning, Deep Learning e Reinforcement Learning che ti permetteranno di risolvere problemi reali e sviluppare soluzioni custom in ambito aziendale. Un modello didattico unico che prevede una live a settimana dopo gli orari lavorativi.\n Unico prerequisito richiesto: saper programmare in Python\n 100% online, studia dove e quando vuoi\n 12 project work in live con i docenti, uno a settimana\n Canale diretto con i docenti, sempre a tua disposizione\n Certificazione finale riconosciuta\n ticket early bird40%SCONTOVuoi ricevere maggiori informazioni sulla prossima Masterclass in partenza?\nCompila il form ⬇️\nDichiaro di aver letto l’informativa privacy e di prestare espresso consenso al trattamento dei dati personali\xa0*RICHIEDI INFORMAZIONISe vuoi accedere con SCONTO EARLY BIRD, prenota ora una call con uno dei docenti.\nFormiamo i professionisti delle migliori aziende al mondo\n\n\nTrustpilot\n\nDURATA TOTALE14 SettimaneLEZIONI ON-DEMAND+65h lezioni online sempre disponibiliLIVE CON I DOCENTI12 lezioni in diretta di project workCERTIFICAZIONEDa aggiungere al CV e al profilo LinkedInSUPPORTO DOCENTIH24 inclusoPerchè scegliere il Percorso di Carriera\nMachine Learning Engineer?\nTutto quello che serve per diventare professionista in Machine Learning è qui\nIl Percorso di Carriera Machine Learning Engineer è la porta d’accesso alle competenze più avanzate in ambito Data Science e Machine Learning.\nÈ il Percorso di Carriera in italiano 100% ONLINE più completo ed aggiornato per ricoprire il ruolo di Machine Learning Engineer.\nUn percorso didattico in modalità di fruizione ibrida: più di 65 ore di lezioni online sempre disponibili e 12 incontri live settimanali di project work con i docenti (fuori dagli orari di lavoro) in cui esercitarsi e chiarire ogni dubbio.\nUn Percorso di Carriera di poco più di 3 mesi che unisce la teoria ad una forte impronta pratica, con esercitazioni su casi d’uso reali e dataset reali che ti permetteranno di padroneggiare le tecniche più avanzate di Machine Learning in qualsiasi ambito applicativo. Impara da professionisti nel campo AI, che ti insegneranno quello che loro stessi fanno ogni giorno.\nScarica la brochureIl percorso più completo al mondoDalle basi fino al Reinforcement Learning imparerai ad utilizzare tutte le tecniche di Machine Learning+65 ore di lezioni on-demandLezioni preregistrate sempre disponibili che ti garantiscono la massima flessibilità nello studio12 Project work in live con i docentiOgni settimana una live dopo gli orari di lavoro in cui lavorare su progetti da aggiungere al tuo portfolioInterazione 24/7 con i docentiSia dal vivo durante le live che all’interno della community Data MastersPercorso cer ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/algotrading-in-python/', 'title': 'Corso di Trading Algoritmico in Python | Data Masters', 'description': 'Impara a Ottimizzare ed Automatizzare le strategie di Trading con Python. Scarica il Sistema di AlgoTrading e aumenta le tue competenze!', 'language': 'it-IT'}, page_content="\n\nCorso di Trading Algoritmico in Python | Data Masters\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediCORSO DI ALGOTRADING\nIN PYTHON\nImpara ad Ottimizzare ed Automatizzare le strategie di Trading con Python. Acquisisci le Skill degli AlgoTrader Professionisti.\n550â‚¬Approccio PRATICOSistema di AlgoTrading in Python pronto all'usoAccesso per sempreGaranzia Soddisfatti o RimborsatiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nDURATA TOTALE12 ore di formazione avanzataLEZIONI48 Video-lezioni online sempre disponibiliSUPPORTO DOCENTIH24 inclusoCERTIFICAZIONEDa aggiungere al CV e al profilo LinkedinGARANZIASoddisfatti o rimborsatiÂ\xa0le skillÂ\xa0DEL CORSO\n\nImparerai tutto sul Trading Automatico, dai fondamentali alle Tecniche di Analisi e al Backtesting. Utilizzerai algoritmi matematici complessi per identificare opportunitÃ\xa0 di trading e prendere decisioni di investimento superando i limiti legati ai bias cognitivi e decisionali umani.\nUtilizzerai Python per creare algoritmi avanzati in grado di automatizzare le tue strategie\n\nTrading FoundationsAnalisi TecnicaSerie Storiche di Dati e TrendAnalisi della VolatilitÃ\xa0Analisi dei VolumiTecniche di AnalisiAI Powered Trading con ChatGPTBacktestingTutti I VANTAGGI DEL TRADING ALGORITMICO\nVelocitÃ\xa0 ed Efficienza\nGli algoritmi analizzano grandi quantitÃ\xa0 di dati in pochi secondi e prendono decisioni in tempo realeÂ\xa0Eliminazione Errore UmanoÂ\xa0\nGli algoritmi sono programmati per seguire regole e istruzioni specifiche eliminando errori umaniBacktesting\nGli algoritmi possono essere testati retroattivamente su dati storici, valutandone l’efficaciaGestione del Rischio\nSi possono eseguire automaticamente ordini di stop loss o di take profit migliorando la gestione del rischioMaggiore Diversificazione\nDiversificazione del portafoglio di investimenti in modo piÃ¹ efficiente rispetto al trading manualeMaggiore Disciplina\nRiduzione della possibilitÃ\xa0 di deviare dal piano di trading a causa di emozioni o di altri fattori esterniPreviousNextPROGRAMMA\nAlgotrading in PythonðŸŽ¥ Introduzione\n\nSurvey Pre-Corso Algotrading in Python\nIntroduzione al corso\nIntroduzione al Trading Online\nDefinizioni\n\nðŸŽ¥ Serie Storiche di Dati e Trend\n\nIntroduzione\nRecupero serie storiche tramite MetaTrader5\nRecupero serie storiche di Crypto-valute\nAnalisi della Distribuzione dei Livelli di Prezzo\nSupporti, Resistenze e Trend-Line\nMedie Mobili\nBande di Bollinger\nBacktesting strategia su Bande di Bollinger\nSAR – Stop And Reverse\nADL – Accumulation Distribution Line\nADX – Average Directional Index\nDonchian Channels\n\nðŸŽ¥ Analisi della VolatilitÃ\xa0\n\nIntroduzione\nRSI – Relative Strength Index\nAnalisi delle Divergenze\nBacktesting Strategie su Divergenze\nCCI – Commodity Channel Index\nMomentum\nIchimoku Cloud\nATR – Average True Range\nROC – Rate of Change\nKST – Know Sure Thing\n\nðŸŽ¥ Analisi dei Volumi\n\nIntroduzione\nMFI – Money Flow Index\nOBV – On Balance Volume\nFI – Force Index\nCMF – Chaikin Money Flow\nProfili Volumetrici\nMarket-Profile\nBacktesting Strategia su Profili Volumetrici\nAnalisi Dinamic ...
#  Document(metadata={'source': 'https://corsi.datamasters.it/offers/8vpgpbtd/checkout', 'title': 'Attention Required! | Cloudflare', 'language': 'en-US'}, page_content=' \n\nAttention Required! | Cloudflare\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPlease enable cookies.\n\n\nSorry, you have been blocked\nYou are unable to access mykajabi.com\n\n\n\n\n\n\n\n\n\n\n\nWhy have I been blocked?\nThis website is using a security service to protect itself from online attacks. The action you just performed triggered the security solution. There are several actions that could trigger this block including submitting a certain word or phrase, a SQL command or malformed data.\n\n\nWhat can I do to resolve this?\nYou can email the site owner to let them know you were blocked. Please include what you were doing when this page came up and the Cloudflare Ray ID found at the bottom of this page.\n\n\n\n\n\nCloudflare Ray ID: 966bb0e6f99d59fb\n•\n\n      Your IP:\n      Click to reveal\n79.35.249.46\n•\n\nPerformance & security by Cloudflare\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://datamasters.it/corsi/matematica-statistica-per-machine-learning/', 'title': 'Corso di Matematica e Statistica per il Machine Learning', 'description': 'Impara online i fondamenti di matematica e statistica per il machine learning: analisi, algebra, insiemi, calcolo combinatorio, probabilità e statistica.', 'language': 'it-IT'}, page_content="\n\nCorso di Matematica e Statistica per il Machine Learning\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediCORSO DI MATEMATICA E STATISTICA PER IL MACHINE LEARNING\nTutte le basi matematiche dell’Intelligenza Artificiale in un unico Bundle.\n2 corsi indispensabili per chiunque voglia diventare un professionista in Data Science, AI e Machine Learning.\nUna preparazione completa e un approccio pratico e accessibile.\n400€\nCON CERTIFICAZIONE FINALE\n\nDue corsi in uno per una formazione completa17 ore di formazione avanzataAccesso per sempre2 certificazioni di fine corsoSupporto docentiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nDURATA TOTALE17 ore di formazione avanzataLEZIONI120 Video-lezioni online sempre disponibiliSUPPORTO DOCENTIH24 inclusoCERTIFICAZIONE2 certificazioni da aggiungere al CV e al profilo LinkedinGARANZIASoddisfatti o rimborsatiTutte le skill matematiche e statistiche per l’ai\n\nAcquisisci solide basi matematiche indispensabili nel mondo della Data Science e del Machine Learning. Un unico flusso formativo che abbraccia analisi matematica e algebra lineare che garantisce non solo la comprensione dei principi matematici ma anche la capacità di applicare queste conoscenze nella risoluzione di problemi reali attraverso un approccio pratico e visuale.\n\nCompleta la formazione matematica essenziale con la teoria degli insiemi, il calcolo combinatorio, la teoria delle probabilità e la statistica, che non possono mancare a chiunque voglia approfondire le proprie conoscenze applicative, imparare a gestire incertezze, calcolare probabilità per modellare eventi complessi, analizzare e interpretare i dati.\nAnalisi MatematicaAlgebra LineareTeoria degli InsiemiCalcolo CombinatorioTeoria delle probabilitàElementi di StatisticaPROGRAMMA\nAnalisi Matematica\nIntroduzione\nGeogebra\nFunzioni ad una variable\nImmagine e Pre-Immagine\nFunzioni su insiemi numerici\nBiettivita e funzione inversa\nRecap su funzioni\nPiano cartesiano e rappresentazione di un punto su GeoGebra\nInsieme di punti su Geogebra\nPrime funzioni su GeoGebra\nDisuguaglianze su GeoGebra\nFunzioni lineari a una variabile\nFunzioni non lineari a una variabile\nTraslare una funzione sul piano\nFunzioni composte\nCombinazioni di funzioni e discontinuità\nPrincipali funzioni di attivazione\nLimiti – Parte 1\nLimiti – Parte 2\nLimiti – Parte 3\nRapporto Incrementale – Definizione\nRapporto Incrementale – Interpretazione del segno\nRapporto Incrementale – Interpretazione del valore assoluto\nDerivata – Limite Rapporto Incrementale\nDerivata – Introduzione\nDerivata come retta tangente al grafico\nRelazione tra derivata e funzione\nPunti Stazionari\nFunzioni a 2 variabili – Introduzione\nFunzioni a 2 variabili – Spazio 3D – Parte 1\nFunzioni a 2 variabili – Spazio 3D – Parte 2\nVisualizzazione di funzioni a due variabili – costante, lineare e non lineare\nDerivate a due variabili – Introduzione\nDerivate a due variabili – Calcolo e significato\nDerivate a due variabili – Piano tangente\nDerivate a due variabili – Gradiente – Parte 1\nDerivate a due variabili – Gradiente ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/machine-learning-starter-kit/', 'title': 'Corso di Machine Learning partendo dalle basi | Data Masters', 'description': 'Il percorso più rapido per imparare il Machine Learning, dalle basi di matematica e statistica, alla programmazione in Python fino agli algoritmi più avanzati.', 'language': 'it-IT'}, page_content='\n\nCorso di Machine Learning partendo dalle basi | Data Masters\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediMACHINE LEARNING sTARTER KIT\nIl percorso più rapido per imparare il Machine Learning, dalle basi di Python fino agli algoritmi più avanzati. Un percorso completo che garantisce non solo la comprensione dei concetti ma anche la capacità di implementarli efficacemente in contesti reali. Scarica tutte le\nEsercitazioni guidate e i Jupyter Notebook per applicare immediatamente ogni nuova abilità.\n597€\nCON CERTIFICAZIONE FINALE\n\nNessun prerequisito50 ore di formazione avanzata15 progetti REALI di Machine Learning scaricabiliAccesso per sempreSupporto docentiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nDURATA TOTALE50 ore di formazione avanzataLEZIONI100+ video-lezioni online sempre disponibiliSUPPORTO DOCENTIH24 inclusoCERTIFICAZIONEDa aggiungere al CV e al profilo LinkedinGARANZIASoddisfatti o rimborsatiPython & Machine Learning: le skill dominanti nell’era AI\nMachine Learning Starter Kit è un pacchetto completo, progettato per fornire tutte le competenze fondamentali in Machine Learning, Data Science e programmazione Python, partendo da Zero. Senza tralasciare i fondamenti di Matematica e Statistica.\nLE SKILL\xa0DEL CORSO\nPythonCalcolo combinatorioElementi di statisticaPandas SciKit-LearnIntroduzione al MLData VisualizationNumpyTeoria delle probabilitàTeoria degli insiemiClusterizzazioneDimensionality reductionNaive BayesKNNSVMAlberi decisionali e metodi di ensembleMetriche per il MLtutte le competenze per diventare la figura professionale più ricercata dalle aziende\nACQUISTA ORATutti gli algoritmi più utilizzati in un unico corso\nREGRESSIONE LINEARE\nL’“Hello World” del Machine Learning, l’algoritmo della regressione lineare è il più semplice algoritmo da applicare e il primo passo per iniziare ad applicare il machine learning.REGRESSIONE LOGISTICA\nUn metodo statistico usato per modellare la probabilità che l’esito sia uno di due possibili stati, fornendo un modo efficace per classificare e analizzare i dati dove le relazioni tra le variabili non sono lineari.K-MEANS\nUna tecnica di clustering non supervisionata che raggruppa dati in cluster distinti basati sulla similarità, iterando fino a raggiungere una disposizione stabile dei centri dei cluster.KNN\nUn metodo di apprendimento supervisionato che classifica un nuovo dato basandosi sulla maggioranza dei voti dei suoi vicini più prossimi, utilizzato per vari compiti di classificazione e regressione.PCA E T-SNE\u200b\u200b\nTecniche avanzate di riduzione della dimensionalità progettate per ridurre lo spazio dei dati preservando la maggior parte delle informazioni originali.NAIVE-BAYES\nUn algoritmo di classificazione basato sul teorema di Bayes, che assume variabili indipendenti. Efficace per la classificazione di testi.SVM\nUn potente algoritmo supervisionato che trova l’iperpiano ottimale per separare le classi di dati. Ideale per riconoscimento di immagini e testi.ALBERI DECISIONALI\nSono un metodo di apprendimento supervisionato nel quale l’algoritmo costruisce un m ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/data-scientist-starter-kit/', 'title': 'Corso online di Data Science e AI per chi parte da zero', 'description': 'Diventa un Data Scientist con il Data Science Starter Kit, un percorso graduale from 0 to Hero studiato su misura per chi comincia.', 'language': 'it-IT'}, page_content="\n\nCorso online di Data Science e AI per chi parte da zero\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccediEntra nel mondo della Data Science partendo da zero\nIl Corso di Data Scientist Starter Kit è all-in-one\xa0ed è progettato per accompagnare gli studenti nell’acquisizione delle competenze fondamentali della Data Science, in modo incrementale, guidando anche chi non possiede un background negli ambiti statistico/matematico o di programmazione.\n197€\nCON CERTIFICAZIONE FINALE\n\nNessun prerequisito27 ore di formazione avanzataEsercitazioni su PROGETTI REALIAccesso per sempreSupporto docentiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nDURATA TOTALE6 settimane (5h/week)LEZIONIOnline sempre disponibiliSUPPORTO DOCENTIH24 inclusoCERTIFICAZIONEDa aggiungere al CV e al profilo LinkedinGARANZIASoddisfatti o rimborsatiOttieni tutte le competenze pratiche per fare della Data Science il tuo lavoro\nImpara a programmare in Python e ad utilizzare le librerie della Data Science: Numpy, Pandas e Scikit-Learn per la Data Engineering. Matplotlib e Seaborn per la Data Visualization.\nTutte le skill necessarie a \nlavorare con la scienza dei Dati\nIL DATA SCIENTIST\nIntroduzione alla quotidianità lavorativa del professionista dei dati più richiesto dalle aziende. Quali sono le sue competenze e cosa rende la Data Science fondamentale per ogni settore.\xa0PYTHON PER LA DATA SCIENCE\xa0\nImpara a programmare in Python e i fondamenti del Object-Oriented Programming. Acquisisci le skill per applicare Python ai processi di Data Analysis.DATA ENGINEERING\nImpara ad applicare le più moderne tecniche di Data Engineering con le librerie Numpy, Pandas e SciKit-Learn per normalizzare, pulire e ottimizzare i tuoi Dataset.DATA VISUALIZATION\nEsplora le principali tecniche di Data Visualization e Data Exploration attraverso l’utilizzo delle librerie Matplotlib e Seaborn per creare Dashboard con grafici che permettano di trarre gli Insight più significativi dai tuoi dati.ESERCITAZIONI\nHERO-LEVEL\nStudio, pre-processing e Data Engineering dei dati relativi alle azioni compiute dagli utenti di un sito web di e-commerce per analizzarne il comportamento.INTRO AL MACHINE LEARNING\nImpara le basi teoriche dell’apprendimento automatico, i campi di applicazione, il processo di implementazione degli algoritmi, i fondamenti di algebra lineare per gli sviluppatori.REGRESSIONE LINEARE\nInizia ad esplorare il mondo del Machine Learning imparando ad utilizzare tecniche fondamentali come la regressione lineare e le Funzioni di Costo.PreviousNexttutte le competenze per diventare la figura professionale più ricercata dalle aziende\nACQUISTA ORAPROGRAMMA DEL CORSO\nFondamenti di Python\nIntroduzione a Python\nInstallazione di Python\nInstallazione di python e configurazione dei virtualenv su Mac OS\nGestione dei Site Packages con Pip e Virtualenv\nEspressioni e Variabili\nControlli di Flusso: booleani e if/else\nLoop: Cicli For\nLoop: Cicli While\nStrutture Dati: Liste\nStrutture Dati: Tuple\nStrutture Dati: Dictionary\nStrutture Dati: Set\nRappresentazione dei Dati: Charset ed Encoding\nStringhe, Encoding e Decoding\ ...
#  Document(metadata={'source': 'https://datamasters.it/corsi/machine-learning-foundations/', 'title': 'Algoritmi di Machine Learning - Corso ed Esercitazioni', 'description': 'Algoritmi di Machine Learning è il corso per apprendere tutti algoritmi di Machine Learning con Python. Corso Completo Teoria + Esercitazioni', 'language': 'it-IT'}, page_content='\n\nAlgoritmi di Machine Learning - Corso ed Esercitazioni\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDataMastersCatalogoCorsiPercorsi di CarrieraNon sai da dove partire? Compila il test di orientamento e ricevi consigli personalizzati Read morePrincipianteIntermedioAvanzatoCategorieCorsi di Generative AICorsi di Data AnalysisCorsi di Data ScienceCorsi di Machine LearningCorsi di Programmazione in PythonTutti i corsiPer le aziendeCommunityCommunity HubBlogChallengesWebinarsAI e Data Skill Report 2025Chi siamoLavora con noiContattiAccedialgoritmi di machine learning\nIl Corso sugli algoritmi di Machine Learning più usati al mondo che ti permette di diventare un esperto nel modo più rapido.\n297€\nCON CERTIFICAZIONE FINALE\n\n20 ore di formazione avanzataApproccio PRATICO20 modelli avanzati di ML da scaricareAccesso per sempreSupporto docentiACQUISTA ORAPaga anche in 3 rate, senza costi aggiuntivi\nDURATA TOTALE20 ore di formazione avanzataLEZIONI54 video lezioni online sempre disponibiliSUPPORTO DOCENTIH24 inclusoCERTIFICAZIONEDa aggiungere al CV e al profilo LinkedinFormiamo i professionisti delle migliori aziende al mondo\n\n\nTrustpilot\n\nTutti gli algoritmi di machine learning più avanzati\nUn viaggio alla scoperta di tutti gli algoritmi fondamentali del Machine Learning, dai più classici ai più avanzati e moderni che vengono utilizzati dai ML Engineer in ogni settore: Alberi Decisionali, Algoritmi di Clustering, Algoritmi Genetici, KNN, SVM, XGBoost, CatBoost, Algoritmi di Ensenble\xa0e tanti altri.\nQuesto corso ti mostrerà tutto quello che devi conoscere per diventare un professionista di AI e ML in un unico corso concentrato e ricco di esercitazioni guidate scaricabili per mettere subito in pratica le competenze.\nIntroduzione al MLDimensionality ReductionKNNAlberi DecisionaliClusteringNaive BayesSVMMetriche per MLProgettato per farti raggiungere rapidamente il livello esperto in ML\nACQUISTA ORAPROGRAMMA DEL CORSO\nIntroduzione al ML\nIntroduzione al Corso\nIntroduzione al Machine Learning\nProcesso di Implementazione\nNo Free Lunch Theorem\nRegressione Lineare\nSGDRegressor e LinearRegression\nRegressione Logistica\nLogisticRegression e make_pipeline\n\nMaggiori informazioniClustering\nClustering\nK-Means\nDB-Scan\nEsercitazione K-Means\nEsercitazione DB-Scan\n\nMaggiori informazioniDimensionality Reduction\nDimensionality Reduction\nPCA – Principal Component Analysis\nt-SNE\nEsercitazione 1 – PCA\nEsercitazione 2 – PCA\nPCA vs t-SNE\n\nMaggiori informazioniNaive Bayes\nIntroduzione e concetti base su Naive Bayes\nNaive Bayes per la spam detection\nApprofondimento Naive Bayes\nBernoulli Naive Bayes\nGaussian Naive Bayes\nGaussian Naive Bayes from scratch\nMultinomial Naive Bayes e Bag of Words\nNaive Bayes per MNIST\n\nMaggiori informazioniKNN\nKNN\nEsercitazione KNN\nKNN – Mahalanobis vs. Euclidean\nKnn e Distanze\n\nMaggiori informazioniSVM\nIntroduzione a SVM\nApprofondimento su Kernel\nVisualizzare i vettori di supporto\nClassificare brand automobilistici con SVM\n\nMaggiori informazioniAlberi decisionali e metodi di ensemble\nAlberi Decisionali\nGini impurity\nEntropy and Information Gain in Decision Trees\nAlberi decisionali su dataset Iris\nPartizionamento spazio decisionale con alberi\nEnsemble learning e random forest\nRandom Forest su dataset Bill Authentication\nBoosting\nAdaboost\nGradient Boosting\nEsercitazione Gradient Boosting\nCenni su XGBoost\nEsercitazione con XGBoost\nCenni su Catboost\nCatboost su dataset Titanic\nEsercitazione su algoritmi di ensemble\n\nMaggiori informa ...

# %%
len(docs[0].page_content)
# Out:
# 12541

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=600, chunk_overlap=400, add_start_index=True
)
all_splits = text_splitter.split_documents(docs)

# %%
len(all_splits)
# Out:
# 923

# %%
len(all_splits[42].page_content)
# Out:
# 421

# %%
all_splits[42].metadata
# Out:
# {'source': 'https://datamasters.it/corsi/',
#  'title': 'Catalogo dei Corsi sullâ€™AI - Data Masters',
#  'description': "Esplora il nostro catalogo e scopri i migliori corsi di formazione continua, sempre aggiornati e con un forte taglio pratico nel campo della Data Science, del Machine Learning e dell'Intelligenza Artificiale.",
#  'language': 'it-IT',
#  'start_index': 10049}

# %%
all_splits[42]
# Out:
# Document(metadata={'source': 'https://datamasters.it/corsi/', 'title': 'Catalogo dei Corsi sullâ€™AI - Data Masters', 'description': "Esplora il nostro catalogo e scopri i migliori corsi di formazione continua, sempre aggiornati e con un forte taglio pratico nel campo della Data Science, del Machine Learning e dell'Intelligenza Artificiale.", 'language': 'it-IT', 'start_index': 10049}, page_content='Come posso contattare i docenti per eventuali domande o problemi?Puoi contattare direttamente i docenti del corso in qualsiasi momento per ricevere supporto e mentorship, nel canale dedicato al corso allâ€™interno della Community di Data Masters.\nPotrÃ² rivedere le lezioni anche dopo aver completato il corso/Percorso di Carriera?SÃ¬, avrai accesso per sempre a tutti i contenuti, inclusi eventuali aggiornamenti futuri.')

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

vectorstore = Chroma.from_documents(documents=all_splits, embedding=OpenAIEmbeddings())

# %%
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 6}) # similarity sta per cosine similarity

# metodi di ricerca alternativi presenti in ChromaDB (ma non in tutti i vector store):
# `similarity_score_threshold` - come similarity ma impostando una soglia minima di accettazione, scarta tutti i documenti sotto la soglia
# `mmr` = maximal marginal relevance - seleziona un insieme di esempi che sono sia simili all'input che diversi tra loro

# %%
retrieved_docs = retriever.invoke("consigliami un corso per iniziare la mia carriera da Data Scientist")

# %%
for doc in retrieved_docs:
    print(doc.metadata)
# Out:
# {'description': 'Diventa un Data Scientist con il Data Science Starter Kit, un percorso graduale from 0 to Hero studiato su misura per chi comincia.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/data-scientist-starter-kit/', 'start_index': 2, 'title': 'Corso online di Data Science e AI per chi parte da zero'}
# {'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 23888, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}
# {'description': 'Diventa un Data Scientist con il Data Science Starter Kit, un percorso graduale from 0 to Hero studiato su misura per chi comincia.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/data-scientist-starter-kit/', 'start_index': 118, 'title': 'Corso online di Data Science e AI per chi parte da zero'}
# {'description': 'Il percorso più rapido per imparare il Machine Learning, dalle basi di matematica e statistica, alla programmazione in Python fino agli algoritmi più avanzati.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/machine-learning-starter-kit/', 'start_index': 123, 'title': 'Corso di Machine Learning partendo dalle basi | Data Masters'}
# {'description': 'Diventa un Data Scientist con il Data Science Starter Kit, un percorso graduale from 0 to Hero studiato su misura per chi comincia.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/data-scientist-starter-kit/', 'start_index': 21015, 'title': 'Corso online di Data Science e AI per chi parte da zero'}
# {'description': 'Algoritmi di Machine Learning è il corso per apprendere tutti algoritmi di Machine Learning con Python. Corso Completo Teoria + Esercitazioni', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/machine-learning-foundations/', 'start_index': 117, 'title': 'Algoritmi di Machine Learning - Corso ed Esercitazioni'}

# %%
retrieved_docs = retriever.invoke("vorrei diventare un Machine Learning Engineer")
for doc in retrieved_docs:
    print(doc.metadata)
# Out:
# {'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 674, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}
# {'description': 'Esplora il Machine Learning senza pre-requisiti tecnici: un corso che permette a tutti di avvicinarsi al mondo ML e AI', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/machine-learning-per-tutti/', 'start_index': 7703, 'title': 'Machine Learning per tutti | Corsi Data Masters'}
# {'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 2024, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}
# {'description': 'Il percorso più rapido per imparare il Machine Learning, dalle basi di matematica e statistica, alla programmazione in Python fino agli algoritmi più avanzati.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/machine-learning-starter-kit/', 'start_index': 26190, 'title': 'Corso di Machine Learning partendo dalle basi | Data Masters'}
# {'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 37704, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}
# {'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 1997, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain import hub

prompt = hub.pull("rlm/rag-prompt")

prompt
# Out:
# C:\Cloud\GitHub\LLMs_MasterClass\.venv\Lib\site-packages\langsmith\client.py:234: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})])

# %%
example_messages = prompt.invoke(
    {"context": "contesto", "question": "domanda"}
).to_messages()

example_messages
# Out:
# [HumanMessage(content="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: domanda \nContext: contesto \nAnswer:", additional_kwargs={}, response_metadata={})]

# %%
print(example_messages[0].content)
# Out:
# You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
# Question: domanda
# Context: contesto
# Answer:

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
rag_chain.invoke("mi piace l'intelligenza artificiale ma non saprei da dove iniziare a studiare, consigliami un corso")
# Out:
# 'Ti consiglio di considerare il corso di Intelligenza Artificiale offerto da Data Masters, che è adatto anche ai principianti senza esperienza. Il corso inizia dalle basi e progredisce verso argomenti più avanzati, ed è disponibile online on-demand. Inoltre, i materiali didattici sono ben strutturati e facili da seguire.'

# %%
# recuperare i documenti selezionati per la generazione

from langchain_core.runnables import RunnableParallel

rag_chain_from_docs = (
    RunnablePassthrough.assign(context=(lambda x: format_docs(x["context"])))
    | prompt
    | llm
    | StrOutputParser()
)

rag_chain_with_source = RunnableParallel(
    {"context": retriever, "question": RunnablePassthrough()}
).assign(answer=rag_chain_from_docs)

# %%
risposta = rag_chain_with_source.invoke("come potrei approfondire tematiche di Deep Learning?")

risposta
# Out:
# {'context': [Document(metadata={'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 38424, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}, page_content='le reti convolutive e ricorrenti, per poi esplorare il mondo del deep learning e delle reti neurali profonde, fino al reinforcement learning. Imparerai a progettare ed applicare algoritmi di machine learning su casi d’uso reali, guidato costantemente da professionisti che sperimentano quotidianamente le innovazioni del settore. Tantissime esercitazioni pratiche su Jupyter Notebook completano il percorso formativo, rendendovi capaci di operare sulle principali librerie oggi utilizzate, come TensorFlow, Keras, Scikit-Learn, Pandas, ecc.'),
#   Document(metadata={'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 35547, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}, page_content='Contenuti Aggiornati e Approfonditi: La masterclass copre gli ultimi sviluppi nel campo del machine learning, con un focus sia teorico che pratico. Gli argomenti vanno dalle basi dell’apprendimento supervisionato e non supervisionato fino alle tecniche avanzate di deep learning e neural networks.\nApproccio Pratico: Oltre alla teoria, il Percorso di Carriera pone grande enfasi sull’applicazione pratica. Ciò include laboratori e progetti hands-on che permettono di applicare direttamente ciò che si impara su dataset reali, utilizzando strumenti e software all’avanguardia.'),
#   Document(metadata={'description': 'Esplora il Machine Learning senza pre-requisiti tecnici: un corso che permette a tutti di avvicinarsi al mondo ML e AI', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/machine-learning-per-tutti/', 'start_index': 1584, 'title': 'Machine Learning per tutti | Corsi Data Masters'}, page_content='Esplorerai anche la distinzione tra intelligenza artificiale, machine learning e deep learning, e approfondirai il ruolo dell’interazione umana nel successo dei progetti di machine learning. Inoltre, acquisirai competenze sulla classificazione degli algoritmi di machine learning utilizzati per l’analisi e la modellazione dei dati.\nIntroduzione al Machine Learning'),
#   Document(metadata={'description': 'Esplora il Machine Learning senza pre-requisiti tecnici: un corso che permette a tutti di avvicinarsi al mondo ML e AI', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/machine-learning-per-tutti/', 'start_index': 7210, 'title': 'Machine Learning per tutti | Corsi Data Masters'}, page_content="ENTRA ORAIntroduzione al MLAcquisirai una comprensione accessibile degli aspetti fondamentali del Machine Learning, comprese le basi teoriche e pratiche. AI, ML e Deep LearningEsplorerai le differenze tra intelligenza artificiale, machine learning e deep learning, comprendendo il ruolo dell'interazione umana.Data ScienceImparerai a classificare gli algoritmi di machine learning utilizzati per l'analisi e la modellazione dei dati.ENTRA ORAImpara dai migliori nel campo del machine learning"),
#   Document(metadata={'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 35496, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}, page_content='Caratteristiche della Machine Learning Masterclass\nContenuti Aggiornati e Approfonditi: La masterclass copre gli ultimi sviluppi nel campo del machine learning, con un focus sia teorico che pratico. Gli argomenti vanno dalle basi dell’apprendimento supervisionato e non supervisionato fino alle tecniche avanzate di deep learning e neural networks.'),
#   Document(metadata={'description': 'Iscriviti alla Machine Learning Masterclass, il Percorso di Carriera in italiano più avanzato ed aggiornato per diventare un professionista un Machine Learning Engineer.', 'language': 'it-IT', 'source': 'https://datamasters.it/corsi/corsi-data-scientist/', 'start_index': 14838, 'title': 'ML Engineer con la Machine Learning Masterclass | Data Masters'}, page_content='Competenze:Deep learning, Reti ricorrenti, Reti convolutive, Serie temporali, Data Visualization, Data engineering, TensorFlow, Keras, Numpy, Pandas, Matplotlib, Metriche di RegressioneModello di generazione di testo: Guida Galattica per Autostoppisti\nProgettazione e implementazione di 3 modelli custom di reti neurali artificiali, basati su LSTM e Trasnformers, per generare testo sullo stile del romanzo “Guida Galattica per Autostoppisti” di Douglas Adams. Implementazione di differenti modalità di preprocessing dei testi.')],
#  'question': 'come potrei approfondire tematiche di Deep Learning?',
#  'answer': 'Per approfondire tematiche di Deep Learning, considera di seguire una masterclass che copra sia gli aspetti teorici che pratici, incluse le reti convolutive e ricorrenti. È utile lavorare su progetti hands-on utilizzando strumenti come TensorFlow e Keras, per applicare ciò che impari su dataset reali. Inoltre, esplora laboratori e esercitazioni pratiche per consolidare le tue competenze.'}
