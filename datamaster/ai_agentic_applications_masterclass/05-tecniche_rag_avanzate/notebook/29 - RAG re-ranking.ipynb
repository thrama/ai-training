# %% [markdown]
# # RAG re-ranking
# #### Sfruttamento della comprensione di un LLM per la selezione dei documenti selezionati dal Vector Store tramite Retriever

# %%
# Importazioni necessarie
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from typing import List
import re
import os
from pydantic import BaseModel, Field

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
# Funzione per caricare documenti di testo
def load_documents(file_path: str) -> List[str]:
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read().split('\n\n')

# %%
# Funzione per creare il Vector Store
def create_vector_store(documents: List[str]):
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=150)
    texts = text_splitter.create_documents(documents)
    
    embeddings = HuggingFaceEmbeddings()
    vector_store = Chroma.from_documents(texts, embeddings)
    return vector_store

# %%
# Funzione per il retrieval iniziale
def initial_retrieval(query: str, vector_store, k=10):
    return vector_store.similarity_search(query, k=k)

# %%
class Relevance(BaseModel):
    """Relevance of a document to a query"""

    relevance: int = Field(default="no", description="a value between 1 and 10 that indicates the relevance of the document to the query")

# %%
# Funzione per il reranking
def rerank_documents(query: str, documents: List[str], llm, verbose=False):
    rerank_prompt = ChatPromptTemplate([
        ("system", "Rate the relevance of a document to a query with a score from 1 to 10"),
        ("user", "Document:\n{document}\n\nQuery:\n{query}")
    ])
    
    rerank_chain = rerank_prompt | llm.with_structured_output(Relevance)
    
    scores = []
    for doc in documents:
        doc_content = doc.page_content
        response = rerank_chain.invoke({"query":query, "document":doc_content})
        score = response.relevance
        scores.append((doc, score))
        if verbose:
            print(doc_content[:50], score)
    
    return sorted(scores, key=lambda x: x[1], reverse=True)  # ritorno la lista di documenti ordinata per rilevanza 
                                                             # rispetto alla query dell'utente

# %%
# Funzione principale RAG
def rag_with_reranking(query: str, vector_store, llm, verbose=False):
    # Retrieval iniziale
    initial_results = initial_retrieval(query, vector_store)

    # Reranking
    reranked_results = rerank_documents(query, initial_results, llm, verbose)
    if verbose:
        print("----------- RANKED RESULTS -----------")
        print(reranked_results)
        print("--------------------------------------")
    # Generazione della risposta sfruttando i 3 documenti più rilevanti tra i 10 selezionati
    context = "\n".join([doc.page_content for doc, _ in reranked_results[:3]])
    
    answer_prompt = PromptTemplate(
        input_variables=["query", "context"],
        template="Basandoti sul seguente contesto, rispondi alla domanda.\n\nContesto: {context}\n\nDomanda: {query}\n\nRisposta:"
    )
    
    answer_chain = answer_prompt | llm
    answer = answer_chain.invoke({"query": query, "context": context})
    
    return answer

# %%
# Caricamento dei documenti
documents = load_documents("data/testo_esempio.txt")

# %%
print(f"{len(documents)} split del documento su `\\n\\n` caricati")
# Out:
# 25 split del documento su `\n\n` caricati

# %%
# Creazione del vector store
vector_store = create_vector_store(documents)

# %%
# Esecuzione della RAG con reranking
query = "Quale evento inaspettato costringe Sofia a tornare nella sua città natale durante il suo percorso universitario a Milano?"  # L'ictus di sua nonna
answer = rag_with_reranking(query, vector_store, llm, verbose=True)
# Out:
# Nei giorni successivi Sofia si ritrovò a dover aff 5
# Ma come spesso accade, proprio quando tutto sembra 10
# La vita universitaria la stava cambiando profondam 2
# I mesi volavano e Sofia si sentiva sempre più part 2
# Da quel momento Marco entrò prepotentemente nella  2
# Era una tiepida mattina di primavera quando Sofia  3
# Il ritorno a Milano fu più difficile del previsto. 2
# L'autunno portò con sé nuovi corsi all'università  2
# Quando finalmente arrivò alla stazione centrale di 2
# Fu in quei giorni difficili che Sofia si rese cont 7
# ----------- RANKED RESULTS -----------
# [(Document(id='804a20c9-adf2-414a-a8f0-31cbc6939e56', metadata={}, page_content="Ma come spesso accade, proprio quando tutto sembra andare per il meglio la vita ti mette davanti a degli ostacoli. Una sera, mentre tornava dal lavoro, Sofia ricevette una telefonata che le gelò il sangue nelle vene. Sua nonna aveva avuto un ictus ed era stata ricoverata d'urgenza. Senza pensarci due volte, Sofia fece una valigia e prese il primo treno per tornare nella sua città natale."), 10), (Document(id='896ed7ff-83ea-4c15-a64e-61ff7842a1d6', metadata={}, page_content='Fu in quei giorni difficili che Sofia si rese conto di quanto fosse cresciuta. Si ritrovò a dover essere forte non solo per se stessa, ma anche per i suoi genitori. Li vedeva distrutti dal dolore e cercava in ogni modo di sostenerli. Si occupava delle pratiche ospedaliere, parlava con i medici, si assicurava che mangiassero e riposassero. Era come se improvvisamente si fosse trovata catapultata nel mondo degli adulti, con tutte le responsabilità che comportava.'), 7), (Document(id='d1c4208c-d9e1-4659-adad-9ba86be91ddc', metadata={}, page_content="Nei giorni successivi Sofia si ritrovò a dover affrontare un altro tipo di dolore. Il dolore di dover lasciare di nuovo la sua famiglia per tornare a Milano. Si sentiva in colpa all'idea di ripartire proprio ora che i suoi genitori avevano più bisogno di lei. Ma sapeva anche che non poteva abbandonare i suoi studi e la vita che si era costruita. Fu una decisione sofferta, ma alla fine decise di tornare. Promise ai genitori che sarebbe tornata più spesso a trovarli e che li avrebbe chiamati ogni giorno."), 5), (Document(id='4db432be-028a-4f4a-a1fb-be5dbffa93a3', metadata={}, page_content="Era una tiepida mattina di primavera quando Sofia uscì di casa, con il cuore che le batteva forte nel petto. L'aria profumava di fiori appena sbocciati e di possibilità infinite. Aveva diciotto anni e tutta la vita davanti a sé, eppure si sentiva come se stesse per affrontare la sfida più grande della sua esistenza. Con passo incerto si avviò verso la stazione, trascinando una pesante valigia piena di sogni e speranze. Lasciava la sua piccola città di provincia per trasferirsi a Milano e iniziare l'università. Era la prima volta che si allontanava da casa per così tanto tempo e l'idea la elettrizzava e la terrorizzava allo stesso tempo."), 3), (Document(id='3a93187b-095e-4024-a8e4-f984c0ce3022', metadata={}, page_content="La vita universitaria la stava cambiando profondamente. Si sentiva crescere giorno dopo giorno, diventare più sicura di sé, più aperta al mondo. Le sue coinquiline erano diventate come sorelle. Passavano le serate a chiacchierare fino a tardi in cucina, condividendo sogni, paure e speranze per il futuro. Nei fine settimana esploravano insieme la vivace vita notturna milanese, tornando all'alba con i piedi doloranti ma il cuore leggero. Sofia si sentiva finalmente libera di essere se stessa, lontana dalle aspettative della piccola comunità in cui era cresciuta."), 2), (Document(id='a0855710-a3c0-4d84-a1b8-50bfa7a85fd5', metadata={}, page_content="I mesi volavano e Sofia si sentiva sempre più parte di Milano. La città frenetica che all'inizio l'aveva spaventata era diventata la sua casa. Conosceva ormai ogni angolo del suo quartiere, aveva i suoi locali preferiti dove andare a studiare o a bere un caffè, si muoveva con disinvoltura tra le vie del centro. L'università la appassionava sempre di più. Ogni lezione era una scoperta, ogni libro letto le apriva nuovi orizzonti. Si era anche fatta un piccolo gruppo di amici con cui condivideva interessi e passioni."), 2), (Document(id='963c56b7-f46a-4841-bd8e-790ca23c22cd', metadata={}, page_content="Da quel momento Marco entrò prepotentemente nella vita di Sofia. Iniziarono a frequentarsi con sempre maggiore assiduità. Lui la portava a scoprire angoli nascosti della città, piccole trattorie dove mangiare la vera cucina milanese, gallerie d'arte underground. Sofia si sentiva rinascere accanto a ...
# --------------------------------------

# %%
print(f"Domanda: {query}")
print(f"Risposta: {answer.content}")
# Out:
# Domanda: Quale evento inaspettato costringe Sofia a tornare nella sua città natale durante il suo percorso universitario a Milano?
# Risposta: Sofia è costretta a tornare nella sua città natale a causa di un evento inaspettato: sua nonna ha avuto un ictus ed è stata ricoverata d'urgenza.

# %%
query = "In quale quartiere di Milano si trova il bistrot dove Sofia trova lavoro come cameriera part-time?"  # Brera
answer = rag_with_reranking(query, vector_store, llm)

print(f"Domanda: {query}")
print(f"Risposta: {answer.content}")
# Out:
# Domanda: In quale quartiere di Milano si trova il bistrot dove Sofia trova lavoro come cameriera part-time?
# Risposta: Il bistrot dove Sofia trova lavoro come cameriera part-time si trova nel quartiere di Brera.

# %%
query = "Come si chiamano le due coinquiline con cui Sofia condivide l'appartamento a Milano?"  # Giulia e Martina
answer = rag_with_reranking(query, vector_store, llm)

print(f"Domanda: {query}")
print(f"Risposta: {answer.content}")
# Out:
# Domanda: Come si chiamano le due coinquiline con cui Sofia condivide l'appartamento a Milano?
# Risposta: Le due coinquiline con cui Sofia condivide l'appartamento a Milano si chiamano Giulia e Martina.
