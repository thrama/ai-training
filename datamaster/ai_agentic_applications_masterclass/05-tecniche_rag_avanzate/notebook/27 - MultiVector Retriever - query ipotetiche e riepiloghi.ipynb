# %% [markdown]
# # MultiVector Retriever
#
# In alcuni task potrebbe essere utile utilizzare più vettori per identificare un singolo documento.
# LangChain ci mette a disposizione l'oggetto **MultiVectorRetriever** per semplificare l'esecuzione di query che sfruttino i multipli vettori disponibili per rintracciare ogni documento.
# Tra i tanti metodi particolari e specifici che potremmo implementare, tre in particolare sono largamente utilizzati:
# * **Chunk più piccoli**: dividere un documento in chunk di differenti dimensioni in modo da sfruttare i chunk più piccoli per identificare al meglio la query dell'utente e i chunk più grandi, che contengono quelli piccoli utilizzati per la ricerca, per restituire chunk di testo più grandi di quelli utilizzati per la ricerca (vedi esempio precedente su `ParentDocumentRetriever`).
# * **Riepilogo**: creazione di un riepilogo per ciascun documento, incorporato poi insieme al (o al posto del) documento.
# * **Query ipotetiche**: creare domande ipotetiche per ogni documento, domande a cui il documento risponderebbe perfettamento, per poi incorporale insieme (o al posto del) documento.
#
# In questo notebook implementeremo gli ultimi due metodi.
#
# ------
#
# ### Paper scientifici che dimostrano l'efficacia delle tecniche di generazione riepiloghi e query ipotetiche
#
#
# | Titolo                    | Approccio                      | Fase di generazione                      | Vantaggi principali                                                                                                          |
# | ------------------------- | ------------------------------ | ---------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------- |
# | *QuOTE*                   | Question-oriented embeddings   | Domande per chunk (indexing)             | Miglior allineamento query‑chunk; alta accuratezza retrieval ([strathweb.com][1], [arXiv][2], [ResearchGate][3], [arXiv][4]) |
# | *HyPE*                    | Prompt embedding precomputati  | Domande pre-generate (indexing)          | Precisione+Recall superiore; zero latenza runtime ([SSRN][5], [ResearchGate][6], [strathweb.com][1])                         |
# | *HyDE*                    | Risposte ipotetiche a runtime  | Risposta generata all’arrivo della query | Miglior precisione zero‑shot; flessibile su domini sconosciuti ([arXiv][7], [Haystack Documentation][8])                     |
# | *Comparativa RAG vs HyDE* | Studio empirico su modelli LLM | Runtime per entrambi                     | Trade‑off tra rilevanza e latenza, RAG più efficiente su edge ([arXiv][9])                                                   |
#
# [1]: https://www.strathweb.com/2025/07/rag-agent-with-hype-pattern-using-semantic-kernel/ "RAG Agent with HyPE Pattern using Semantic Kernel"
# [2]: https://arxiv.org/html/2502.10976v1 "QuOTE: Question-Oriented Text Embeddings"
# [3]: https://www.researchgate.net/publication/389090378_QuOTE_Question-Oriented_Text_Embeddings "(PDF) QuOTE: Question-Oriented Text Embeddings"
# [4]: https://arxiv.org/abs/2502.10976 "QuOTE: Question-Oriented Text Embeddings"
# [5]: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5139335 "Bridging the Question-Answer Gap in Retrieval-Augmented ..."
# [6]: https://www.researchgate.net/publication/393738017_Bridging_the_Question-Answer_Gap_in_Retrieval-Augmented_Generation_Hypothetical_Prompt_Embeddings "Bridging the Question-Answer Gap in Retrieval-Augmented ..."
# [7]: https://arxiv.org/abs/2212.10496 "Precise Zero-Shot Dense Retrieval without Relevance Labels"
# [8]: https://docs.haystack.deepset.ai/docs/hypothetical-document-embeddings-hyde "Hypothetical Document Embeddings (HyDE)"
# [9]: https://arxiv.org/abs/2506.21568 "Assessing RAG and HyDE on 1B vs. 4B-Parameter ..."

# %%
# caricamento di documenti 

from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

loaders = [
    TextLoader("data/dialoghi/dialogo.txt"),
    TextLoader("data/dialoghi/dialogo2.txt"),
    TextLoader("data/dialoghi/dialogo3.txt"),
    TextLoader("data/dialoghi/dialogo4.txt"),
    TextLoader("data/dialoghi/dialogo5.txt"),
]
docs = []
for loader in loaders:
    docs.extend(loader.load())
text_splitter = RecursiveCharacterTextSplitter(chunk_size=650)
docs = text_splitter.split_documents(docs)

# %%
print(len(docs), "chunk creati")
# Out:
# 33 chunk creati

# %% [markdown]
# ## Riepilogo

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

chain = (
    {"doc": lambda x: x.page_content}
    | ChatPromptTemplate.from_template("Summarize the following document:\n\n{doc}")
    | ChatOpenAI(model="gpt-4o-mini")
    | StrOutputParser()
)

# %%
summaries = chain.batch(docs, {"max_concurrency": 5})

# %%
for summ in summaries:
    print(summ, "\n\n-------------\n\n")
# Out:
# In a clothing store, a customer asks a sales assistant for help. The customer expresses interest in trying on a pair of black pants displayed in the window and specifies their size as 50. The sales assistant promptly provides the requested pants.
#
# -------------
#
#
# In a conversation between a customer and a shop assistant, they discuss the recent weather changes. The customer expresses relief at the cooler weather today, noting that yesterday felt like July. The shop assistant agrees, mentioning how hot it was, and describes changing shirts multiple times due to the heat. They recall a sudden storm that soaked the customer on their way home. The shop assistant remarks on the typical pattern of summer storms following heatwaves, while the customer hopes the pleasant weather holds out as they plan to go downtown later.
#
# -------------
#
#
# In a casual conversation between a shopkeeper and a customer, they discuss their shared interest in sports, specifically a recent basketball game between the Lakers and the Celtics. Both express excitement over the game's highlight moments, particularly Tatum's impressive last-second three-pointer. The shopkeeper mentions being underwhelmed by LeBron's performance, while the customer acknowledges his age as a factor. The customer stayed up late to watch the game, whereas the shopkeeper fell asleep after overtime and later had to catch up on the highlights on his phone.
#
# -------------
#
#
# In the conversation, one person mentions that they fell asleep right after overtime and had to watch the highlights on their phone the next morning. The other person responds by saying that they at least managed to stay awake until then, but they woke up feeling exhausted. However, they feel it was worth it.
#
# -------------
#
#
# A customer is in a store trying on pants. After trying on a pair, they find them a bit tight and ask for a larger size. The salesperson informs them that size 52 is out of stock in that color but offers alternatives in brown, red, and grey. The customer declines the brown and decides to try the grey option instead.
#
# -------------
#
#
# Un cliente prova dei pantaloni grigi e trova che sono belli e la taglia è perfetta. Chiede il prezzo, che è di 85€, ma scopre che non sono in sconto poiché fanno parte della nuova collezione estiva, mentre i saldi riguardano solo la merce invernale. Il cliente commenta che i pantaloni sembrano un po' cari, ma il commesso sottolinea la qualità del materiale, essendo 100% cotone. Il cliente decide di acquistarli e chiede se può pagare con carta di credito, ricevendo conferma dal commesso. Infine, il cliente decide di prendere i pantaloni e ringrazia il commesso.
#
# -------------
#
#
# In the conversation, a shop assistant thanks a customer and expresses hope that it won't rain again that evening, as well as optimism for the Lakers' performance in their next game. The customer agrees and wishes the shop assistant a good day before leaving. The interaction is friendly and casual.
#
# -------------
#
#
# In a gym conversation, Athlete 1 greets Athlete 2 and learns that Athlete 2 is trying to improve their endurance. Athlete 1 suggests gradually increasing their cardio from 30 minutes of running three times a week by adding 5 minutes each week. Additionally, Athlete 1 emphasizes the importance of a balanced diet, recommending adequate protein and complex carbohydrates.
#
# -------------
#
#
# Atleta 2 chiede consigli su dieta e allenamento a Atleta 1. Atleta 1 suggerisce di seguire un'alimentazione equilibrata con buone quantità di proteine e carboidrati complessi. Per migliorare la resistenza muscolare, consiglia di fare circuiti di allenamento ad alta intensità. Atleta 2 esprime interesse per questo tipo di allenamento e chiede a Atleta 1 su cosa stia lavorando. Atleta 1 risponde che si sta concentrando sull'aumento della massa muscolare attraverso allenamenti con i pesi.
#
# -------------
#
#
# Atleta 1 e Atleta 2 discutono dei loro allenamenti. Atleta 1 sta cercando di aumentare la massa muscolare e segue un programma suddiviso per gruppi muscolari, concentrandosi su diverse parti del corpo in giorni specifici. Atleta 2 chiede se ha notato miglioramenti e Atleta 1 conferma i progressi, sottolineando l'importanza della costanza e della pazienza. La conversazione si conclude con Atleta 2 che ringrazia per i consigli.
#
# -------------
#
#
# Atleta 1 expresses satisfaction with the progress they are making, emphasizing the importance of consistency and patience. Atleta 2 thanks them for the advice and says goodbye, while Atleta 1 wishes them good luck with their training and looks forward to seeing them again soon.
#
# -------------
#
#
# In una conversazione davanti alla scuola, alcune mamme si scambiano saluti e si lamentano della stanchezza accumulata dopo una settimana intensa tra lavoro e figli. Una di loro esprime il desiderio di avere una giornata solo per se stessa.
#
# -------------
#
#
# In una conversazione tra mamme, Mamma 1 chiede come stanno andando a scuola i loro bambini. Mamma 2 condivide che Marco sta avendo difficoltà in matematica, ma stanno lavorando con un tutor. Mamma 3 dice che Laura ama la matematica, ma trova noiosa la storia. Mamma 4 menziona che anche Emma ha difficoltà con le date di storia, ma è brava in italiano. Infine, Mamma 1 nota che Pietro è bravo in tutte le materie, ma è molto disordinato e fatica a tenere in ordine il suo zaino e i quaderni.
#
# -------------
#
#
# Le mamme discutono della nuova maestra di inglese, che sembra essere molto competente. Una mamma menziona l'entusiasmo della sua figlia per le lezioni stimolanti, mentre un'altra spera che la nuova maestra possa aiutare sua figlia Emma, che ha sempre trovato difficile l'inglese. Un'altra mamma condivide che suo figlio Pietro è felice dell'approccio didattico della maestra, che include giochi e attività divertenti.
#
# -------------
#
#
# Un gruppo di mamme sta discutendo del prossimo incontro con i genitori, previsto per giovedì prossimo alle 17:00. Durante l'incontro si parlerà dei progressi dei bambini e dei futuri progetti scolastici. Una mamma chiede anche informazioni riguardo a eventuali contributi necessari da parte dei genitori.
#
# -------------
#
#
# Le mamme discutono del nuovo laboratorio di scienze, esprimendo entusiasmo per i loro figli. Mamma 3 menziona che Laura è eccitata di partecipare, mentre Mamma 4 condivide che Emma sogna di diventare una scienziata. Mamma 1 commenta l’interesse di Pietro, ma spera che non causino troppo disordine durante le attività.
#
# -------------
#
#
# In this conversation, several mothers discuss their plans for the upcoming weekend. Mamma 3 mentions that her family is going to the park, hoping for nice weather so the children can play. Mamma 4 shares that her family will visit the grandparents, as the children miss them. Mamma 1 states they plan to go to the cinema to watch a new children's film. Mamma 2 suggests that they could also go on a mountain excursion, as the kids love exploring.
#
# -------------
#
#
# In una conversazione tra mamme, si discute di come i loro mariti si stanno organizzando con i bambini. Una mamma menziona che suo marito è molto impegnato con il lavoro, ma cercano di trascorrere del tempo insieme nel fine settimana. Un'altra mamma dice che il suo marito cerca di aiutare il più possibile, anche se a volte è come gestire un altro bambino. Un'altra ancora condivide che suo marito è molto coinvolto, occupandosi spesso dei compiti, soprattutto in materie che lei non comprende. Infine, un’altra mamma sottolinea che i loro mariti fanno del loro meglio per essere presenti, esprimendo gratitudine per avere mariti collaborativi.
#
# -------------
#
#
# The document consists of a brief conversation among four mothers as they prepare to leave. Mamma 4 expresses excitement about the group heading out, while Mamma 1 confirms it's time to go and says they will see each other the next day. Mamma 2 and Mamma 3 say goodbye, wishing each other a good day and evening.
#
# -------------
#
#
# In un supermercato, due clienti hanno una conversazione. Cliente 1 chiede dove trovare la farina integrale e Cliente 2 risponde che si trova nel corridoio 5, menzionando di essere lì per comprare ingredienti per una cena speciale. Cliente 2 prevede di preparare un risotto ai funghi, mentre Cliente 1 sta pianificando di fare una torta di mele seguendo una ricetta della nonna, ma con l'intenzione di renderla più leggera.
#
# -------------
#
#
# Cliente 1 sta cercando di preparare una torta di mele con una ricetta di famiglia, ma vuole renderla più leggera. Cliente 2 suggerisce di usare mele biologiche, che si trovano nel reparto frutta e verdura, affermando che sono molto buone. Cliente 1 apprezza il consiglio e decide di provarle.
#
# -------------
#
#
# Due clienti si trovano nel reparto frutta e verdura di un negozio. Cliente 1 commenta sulla bellezza delle zucchine e considera di aggiungerle alla sua torta salata. Cliente 2 approva l'idea delle zucchine e informa di dover comprare spinaci freschi per il suo contorno. Entrambi esprimono il loro amore per gli spinaci e Cliente 2 decide di prenderne un paio di confezioni. Alla fine, Cliente 1 dichiara di aver preso tutto il necessario dalla frutta e verdura e propone di andare al reparto latticini.
#
# -------------
#
#
# Due clienti discutono le loro liste della spesa. Cliente 2 ha bisogno di burro e formaggio per il risotto, mentre cliente 1 cerca latte e yogurt, in particolare yogurt greco che usa per i dolci. Cliente 2 esprime apprezzamento per lo yogurt greco, indicandolo come ideale per colazioni sane, e nota un'offerta sul burro. Cliente 1 decide di prendere del burro anche per sé.
#
# -------------
#
#
# Due clienti stanno facendo acquisti al supermercato. Cliente 2 ha bisogno di pollo per il secondo piatto, mentre Cliente 1 la accompagna per trovare idee per la cena. Cliente 2 decide di prendere un paio di petti di pollo e chiede se Cliente 1 ha mai provato a preparare il pollo al curry, il quale è uno dei piatti preferiti di Cliente 1. Cliente 1 poi ricorda a Cliente 2 di comprare il pane, quindi entrambi si dirigono verso il reparto panetteria.
#
# -------------
#
#
# Due clienti stanno facendo la spesa e notano il profumo del pane integrale appena sfornato. Cliente 2 decide di acquistare due filoni di pane, mentre Cliente 1 opta per un filone e alcuni panini per la colazione del giorno dopo. Dopo aver verificato di avere tutto ciò di cui hanno bisogno, decidono di andare alle casse.
#
# -------------
#
#
# In this conversation, two customers discuss their shopping experience. Cliente 2 expresses hope that there won't be a long line, and they decide to go to a relatively free checkout. Cliente 1 confirms they found everything they needed, thanks to Cliente 2's help, and appreciates shopping together. They both agree it was a fun and quick trip, and they look forward to their next shopping outing. They end the conversation by wishing each other a good dinner and dessert.
#
# -------------
#
#
# Durante la pausa caffè in ufficio, i dipendenti si scambiano saluti e commentano la giornata intensa. Uno di loro esprime il desiderio che arrivi il weekend, mentre un altro menziona le nuove direttive del capo.
#
# -------------
#
#
# In the conversation, employees discuss upcoming important changes related to remote work policies. Employee 1 mentions having read about these changes, and Employee 2 confirms that there will be a reduction in the number of days employees can work from home. Employee 3 expresses disappointment, as they enjoyed the convenience of working from home. Employee 4 agrees with the preference for remote work but understands the need for more in-office presence to enhance teamwork.
#
# -------------
#
#
# In una conversazione tra impiegati, uno di loro suggerisce che con più pause caffè insieme ci si possa divertire di più. Un altro menziona la nuova macchina da caffè, lodando la qualità dell'espresso che produce, migliore rispetto alla precedente. Gli altri impiegati concordano, esprimendo la loro soddisfazione per la macchina, considerandola un aspetto positivo in una settimana altrimenti difficile.
#
# -------------
#
#
# In un incontro tra quattro impiegati, si discute dei progetti in corso. Il primo impiegato si sente sopraffatto dal lavoro. Il secondo riferisce che il suo progetto sta andando bene, ma presenta complicazioni improvvise. Il terzo sta preparando una presentazione per i clienti, che è quasi completa, ma richiede ancora alcune rifiniture. Infine, il quarto impiegato è impegnato a rispettare scadenze, definendo la situazione come una corsa contro il tempo.
#
# -------------
#
#
# Quattro impiegati discutono del lavoro e della frenesia della giornata lavorativa. Riconoscono l'importanza del supporto reciproco tra colleghi e delle pause caffè come momento di ricarica e socializzazione. Alla fine della conversazione, uno di loro chiede se qualcuno ha piani per il weekend.
#
# -------------
#
#
# In una conversazione tra quattro impiegati, ciascuno condivide i propri piani per il weekend. Impiegato 1 prevede di andare al mare se il tempo è favorevole per rilassarsi. Impiegato 2 preferisce un'escursione in montagna per godere dell'aria aperta. Impiegato 3 intende visitare una nuova mostra d'arte in città. Infine, Impiegato 4 ha intenzione di rilassarsi a casa, magari guardando film o leggendo un libro.
#
# -------------
#
#
# In un breve scambio tra quattro impiegati, si parla di come sia importante prendersi delle pause e godersi il tempo libero. Dopo aver riconosciuto che è quasi ora di tornare al lavoro, si salutano con un promemoria di una prossima pausa caffè tra qualche ora. La conversazione è leggera e amichevole, riflettendo un ambiente di lavoro positivo.
#
# -------------

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_classic.storage import InMemoryByteStore
from langchain_classic.retrievers.multi_vector import MultiVectorRetriever
import uuid

vectorstore = Chroma(collection_name="summaries", embedding_function=OpenAIEmbeddings())

# salvataggio dei documenti originali in memoria
store = InMemoryByteStore()

id_key = "doc_id"

retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    byte_store=store,
    id_key=id_key,
)
doc_ids = [str(uuid.uuid4()) for _ in docs]

# %%
doc_ids
# Out:
# ['8eba7ac6-2e56-4cae-ba7a-ec971e62c241',
#  '0601f08c-8eef-4f3c-ac01-f5ed0f80988c',
#  'd468d9e7-640f-424a-92b5-fdb72871b011',
#  '06cf7b53-e88f-41b9-b79d-698b72b5aaf2',
#  '70407837-28de-481e-80f4-cb5e5aa94cef',
#  'f16ec6c4-4a46-49ed-a30c-1951a8c1d617',
#  '8befab80-4a75-4f12-b5f3-389c49dce86e',
#  'f1533ceb-f0a1-4c6e-8c15-e2e4c6c99078',
#  '1725e07e-0d9b-42f9-8af1-4a1a9a78946e',
#  'cf35a1b0-9d12-46ec-9e05-99d9dbc6235e',
#  '8519b2f0-9b15-4c31-83d9-cef782186b5c',
#  'afa0ffa3-c270-43fb-9508-0572b6c0de63',
#  '49b206d4-d843-4bbb-a46b-2dc07182374e',
#  '09b781b2-4fe0-44c2-9cc0-81ac85399ecf',
#  'd3a3a8d1-d66f-4c7e-a527-6d82a7ff252e',
#  '998b0ed0-d753-48f6-a420-565a27cbbe6c',
#  'd837b4af-aff3-464d-8af5-04aae5044fef',
#  '83080eea-2ee7-4197-ae69-831a84965ea5',
#  '62c61a8b-a26f-4ef6-acd3-643e1e700e06',
#  'aae0d420-08e9-429c-8308-d1e0c4acb421',
#  '13d4e4f2-aef4-405d-9c02-f97214218fab',
#  '586bdc04-7ad5-4412-9a32-b832927d76c5',
#  '6cf06ef4-6c47-4e27-b578-c9cb3d8b45b9',
#  '14da6cfb-5a6d-44ee-95a6-5663e4c6e088',
#  'bdf8a5a4-2833-4ece-a189-0e841577ff48',
#  '70179342-ba60-4e65-8165-181679dc2dcf',
#  '62025e4d-484f-40bc-bee9-87e31162ebe4',
#  'da2fecd9-ef2a-48b0-af8c-d98eae9a38b8',
#  'a20b2573-7872-4611-8bc5-7f927e034d6c',
#  '7117b443-1d10-4b51-a03b-bd4aa2e90a24',
#  'fe070abf-33e0-4bd8-b77a-b20e53faa6e3',
#  'cb2c5206-a808-4c31-82e2-3cbb2031c31c',
#  '5763c625-47b2-48a0-975f-4b6177f4c577']

# %%
from langchain_core.documents import Document

# creazione documenti con identificativo univoco nei metadata e sintesi del testo iniziale come contenuto
summary_docs = [
    Document(page_content=s, metadata={id_key: doc_ids[i]}) for i, s in enumerate(summaries)
]

# %%
summary_docs
# Out:
# [Document(metadata={'doc_id': '8eba7ac6-2e56-4cae-ba7a-ec971e62c241'}, page_content='In a clothing store, a customer asks a sales assistant for help. The customer expresses interest in trying on a pair of black pants displayed in the window and specifies their size as 50. The sales assistant promptly provides the requested pants.'),
#  Document(metadata={'doc_id': '0601f08c-8eef-4f3c-ac01-f5ed0f80988c'}, page_content='In a conversation between a customer and a shop assistant, they discuss the recent weather changes. The customer expresses relief at the cooler weather today, noting that yesterday felt like July. The shop assistant agrees, mentioning how hot it was, and describes changing shirts multiple times due to the heat. They recall a sudden storm that soaked the customer on their way home. The shop assistant remarks on the typical pattern of summer storms following heatwaves, while the customer hopes the pleasant weather holds out as they plan to go downtown later.'),
#  Document(metadata={'doc_id': 'd468d9e7-640f-424a-92b5-fdb72871b011'}, page_content="In a casual conversation between a shopkeeper and a customer, they discuss their shared interest in sports, specifically a recent basketball game between the Lakers and the Celtics. Both express excitement over the game's highlight moments, particularly Tatum's impressive last-second three-pointer. The shopkeeper mentions being underwhelmed by LeBron's performance, while the customer acknowledges his age as a factor. The customer stayed up late to watch the game, whereas the shopkeeper fell asleep after overtime and later had to catch up on the highlights on his phone."),
#  Document(metadata={'doc_id': '06cf7b53-e88f-41b9-b79d-698b72b5aaf2'}, page_content='In the conversation, one person mentions that they fell asleep right after overtime and had to watch the highlights on their phone the next morning. The other person responds by saying that they at least managed to stay awake until then, but they woke up feeling exhausted. However, they feel it was worth it.'),
#  Document(metadata={'doc_id': '70407837-28de-481e-80f4-cb5e5aa94cef'}, page_content='A customer is in a store trying on pants. After trying on a pair, they find them a bit tight and ask for a larger size. The salesperson informs them that size 52 is out of stock in that color but offers alternatives in brown, red, and grey. The customer declines the brown and decides to try the grey option instead.'),
#  Document(metadata={'doc_id': 'f16ec6c4-4a46-49ed-a30c-1951a8c1d617'}, page_content="Un cliente prova dei pantaloni grigi e trova che sono belli e la taglia è perfetta. Chiede il prezzo, che è di 85€, ma scopre che non sono in sconto poiché fanno parte della nuova collezione estiva, mentre i saldi riguardano solo la merce invernale. Il cliente commenta che i pantaloni sembrano un po' cari, ma il commesso sottolinea la qualità del materiale, essendo 100% cotone. Il cliente decide di acquistarli e chiede se può pagare con carta di credito, ricevendo conferma dal commesso. Infine, il cliente decide di prendere i pantaloni e ringrazia il commesso."),
#  Document(metadata={'doc_id': '8befab80-4a75-4f12-b5f3-389c49dce86e'}, page_content="In the conversation, a shop assistant thanks a customer and expresses hope that it won't rain again that evening, as well as optimism for the Lakers' performance in their next game. The customer agrees and wishes the shop assistant a good day before leaving. The interaction is friendly and casual."),
#  Document(metadata={'doc_id': 'f1533ceb-f0a1-4c6e-8c15-e2e4c6c99078'}, page_content='In a gym conversation, Athlete 1 greets Athlete 2 and learns that Athlete 2 is trying to improve their endurance. Athlete 1 suggests gradually increasing their cardio from 30 minutes of running three times a week by adding 5 minutes each week. Additionally, Athlete 1 emphasizes the importance of a balanced diet, recommending adequate protein and complex carbohydrates.'),
#  Document(metadata={'doc_id': '1725e07e-0d9b-42f9-8af1-4a1a9a78946e'}, page_content="Atleta 2 chiede consigli su dieta e allenamento a Atleta 1. Atleta 1 suggerisce di seguire un'alimentazione equilibrata con buone quantità di proteine e carboidrati complessi. Per migliorare la resistenza muscolare, consiglia di fare circuiti di allenamento ad alta intensità. Atleta 2 esprime interesse per questo tipo di allenamento e chiede a Atleta 1 su cosa stia lavorando. Atleta 1 risponde che si sta concentrando sull'aumento della massa muscolare attraverso allenamenti con i pesi."),
#  Document(metadata={'doc_id': 'cf35a1b0-9d12-46ec-9e05-99d9dbc6235e'}, page_content="Atleta 1 e Atleta 2 discutono dei loro allenamenti. Atleta 1 sta cercando di aumentare la massa muscolare e segue un programma suddiviso per gruppi muscolari, concentrandosi su diverse parti del corpo in giorni specifici. Atleta 2 chiede se ha notato miglioramenti e Atleta 1 conferma i progressi, sottolineando l'importanza della costanza e della pazienza. La conversazione si conclude con Atleta 2 che ringrazia per i consigli."),
#  Document(metadata={'doc_id': '8519b2f0-9b15-4c31-83d9-cef782186b5c'}, page_content='Atleta 1 expresses satisfaction with the progress they are making, emphasizing the importance of consistency and patience. Atleta 2 thanks them for the advice and says goodbye, while Atleta 1 wishes them good luck with their training and looks forward to seeing them again soon.'),
#  Document(metadata={'doc_id': 'afa0ffa3-c270-43fb-9508-0572b6c0de63'}, page_content='In una conversazione davanti alla scuola, alcune mamme si scambiano saluti e si lamentano della stanchezza accumulata dopo una settimana intensa tra lavoro e figli. Una di loro esprime il desiderio di avere una giornata solo per se stessa.'),
#  Document(metadata={'doc_id': '49b206d4-d843-4bbb-a46b-2dc07182374e'}, page_content='In una conversazione tra mamme, Mamma 1 chiede come stanno andando a scuola i loro bambini. Mamma 2 condivide che Marco sta avendo difficoltà in matematica, ma stanno lavorando con un tutor. Mamma 3 dice che Laura ama la matematica, ma trova noiosa la storia. Mamma 4 menziona che anche Emma ha difficoltà con le date di storia, ma è brava in italiano. Infine, Mamma 1 nota che Pietro è bravo in tutte le materie, ma è molto disordinato e fatica a tenere in ordine il suo zaino e i quaderni.'),
#  Document(metadata={'doc_id': '09b781b2-4fe0-44c2-9cc0-81ac85399ecf'}, page_content="Le mamme discutono della nuova maestra di inglese, che sembra essere molto competente. Una mamma menziona l'entusiasmo della sua figlia per le lezioni stimolanti, mentre un'altra spera che la nuova maestra possa aiutare sua figlia Emma, che ha sempre trovato difficile l'inglese. Un'altra mamma condivide che suo figlio Pietro è felice dell'approccio didattico della maestra, che include giochi e attività divertenti."),
#  Document(metadata={'doc_id': 'd3a3a8d1-d66f-4c7e-a527-6d82a7ff252e'}, page_content="Un gruppo di mamme sta discutendo del prossimo incontro con i genitori, previsto per giovedì prossimo alle 17:00. Durante l'incontro si parlerà dei progressi dei bambini e dei futuri progetti scolastici. Una mamma chiede anche informazioni riguardo a eventuali contributi necessari da parte dei genitori."),
#  Document(metadata={'doc_id': '998b0ed0-d753-48f6-a420-565a27cbbe6c'}, page_content='Le mamme discutono del nuovo laboratorio di scienze, esprimendo entusiasmo per i loro figli. Mamma 3 menziona che Laura è eccitata di partecipare, mentre Mamma 4 condivide che Emma sogna di diventare una scienziata. Mamma 1 commenta l’interesse di Pietro, ma spera che non causino troppo disordine durante le attività.'),
#  Document(metadata={'doc_id': 'd837b4af-aff3-464d-8af5-04aae5044fef'}, page_content="In this conversation, several mothers discuss their plans for the upcoming weekend. Mamma 3 mentions that her family is going to the park, hoping for nice weather so the children can play. Mamma 4 shares that her family will visit the grandparents, as the children miss them. Mamma 1 states they plan to go to the cinema to watch a new children's film. Mamma 2 suggests that they could also go on a mountain excursion, as the kids love exploring."),
#  Document(metadata={'doc_id': '83080eea-2ee7-4197-ae69-831a84965ea5'}, page_content="In una conversazione tra mamme, si discute di come i loro mariti si stanno organizzando con i bambini. Una mamma menziona che suo marito è molto impegnato con il lavoro, ma cercano di trascorrere del tempo insieme nel fine settimana. Un'altra mamma dice che il suo marito cerca di aiutare il più possibile, anche se a volte è come gestire un altro bambino. Un'altra ancora condivide che suo marito è molto coinvolto, occupandosi spesso dei compiti, soprattutto in materie che lei non comprende. Infine, un’altra mamma sottolinea che i loro mariti fanno del loro meglio per essere presenti, esprimendo gratitudine per avere mariti collaborativi."),
#  Document(metadata={'doc_id': '62c61a8b-a26f-4ef6-acd3-643e1e700e06'}, page_content="The document consists of a brief conversation among four mothers as they prepare to leave. Mamma 4 expresses excitement about the group heading out, while Mamma 1 confirms it's time to go and says they will see each other the next day. Mamma 2 and Mamma 3 say goodbye, wishing each other a good day and evening."),
#  Document(metadata={'doc_id': 'aae0d420-08e9-429c-8308-d1e0c4acb421'}, page_content="In un supermercato, due clienti hanno una conversazione. Cliente 1 chiede dove trovare la farina integrale e Cliente 2 risponde che si trova nel corridoio 5, menzionando di essere lì per comprare ingredienti per una cena speciale. Cliente 2 prevede di preparare un risotto ai funghi, mentre Cliente 1 sta pianificando di fare una torta di mele seguendo una ricetta della nonna, ma con l'intenzione di renderla più leggera."),
#  Document(metadata={'doc_id': '13d4e4f2-aef4-405d-9c02-f97214218fab'}, page_content='Cliente 1 sta cercando di preparare una torta di mele con una ricetta di famiglia, ma vuole renderla più leggera. Cliente 2 suggerisce di usare mele biologiche, che si trovano nel reparto frutta e verdura, affermando che sono molto buone. Cliente 1 apprezza il consiglio e decide di provarle.'),
#  Document(metadata={'doc_id': '586bdc04-7ad5-4412-9a32-b832927d76c5'}, page_content="Due clienti si trovano nel reparto frutta e verdura di un negozio. Cliente 1 commenta sulla bellezza delle zucchine e considera di aggiungerle alla sua torta salata. Cliente 2 approva l'idea delle zucchine e informa di dover comprare spinaci freschi per il suo contorno. Entrambi esprimono il loro amore per gli spinaci e Cliente 2 decide di prenderne un paio di confezioni. Alla fine, Cliente 1 dichiara di aver preso tutto il necessario dalla frutta e verdura e propone di andare al reparto latticini."),
#  Document(metadata={'doc_id': '6cf06ef4-6c47-4e27-b578-c9cb3d8b45b9'}, page_content="Due clienti discutono le loro liste della spesa. Cliente 2 ha bisogno di burro e formaggio per il risotto, mentre cliente 1 cerca latte e yogurt, in particolare yogurt greco che usa per i dolci. Cliente 2 esprime apprezzamento per lo yogurt greco, indicandolo come ideale per colazioni sane, e nota un'offerta sul burro. Cliente 1 decide di prendere del burro anche per sé."),
#  Document(metadata={'doc_id': '14da6cfb-5a6d-44ee-95a6-5663e4c6e088'}, page_content='Due clienti stanno facendo acquisti al supermercato. Cliente 2 ha bisogno di pollo per il secondo piatto, mentre Cliente 1 la accompagna per trovare idee per la cena. Cliente 2 decide di prendere un paio di petti di pollo e chiede se Cliente 1 ha mai provato a preparare il pollo al curry, il quale è uno dei piatti preferiti di Cliente 1. Cliente 1 poi ricorda a Cliente 2 di comprare il pane, quindi entrambi si dirigono verso il reparto panetteria.'),
#  Document(metadata={'doc_id': 'bdf8a5a4-2833-4ece-a189-0e841577ff48'}, page_content='Due clienti stanno facendo la spesa e notano il profumo del pane integrale appena sfornato. Cliente 2 decide di acquistare due filoni di pane, mentre Cliente 1 opta per un filone e alcuni panini per la colazione del giorno dopo. Dopo aver verificato di avere tutto ciò di cui hanno bisogno, decidono di andare alle casse.'),
#  Document(metadata={'doc_id': '70179342-ba60-4e65-8165-181679dc2dcf'}, page_content="In this conversation, two customers discuss their shopping experience. Cliente 2 expresses hope that there won't be a long line, and they decide to go to a relatively free checkout. Cliente 1 confirms they found everything they needed, thanks to Cliente 2's help, and appreciates shopping together. They both agree it was a fun and quick trip, and they look forward to their next shopping outing. They end the conversation by wishing each other a good dinner and dessert."),
#  Document(metadata={'doc_id': '62025e4d-484f-40bc-bee9-87e31162ebe4'}, page_content='Durante la pausa caffè in ufficio, i dipendenti si scambiano saluti e commentano la giornata intensa. Uno di loro esprime il desiderio che arrivi il weekend, mentre un altro menziona le nuove direttive del capo.'),
#  Document(metadata={'doc_id': 'da2fecd9-ef2a-48b0-af8c-d98eae9a38b8'}, page_content='In the conversation, employees discuss upcoming important changes related to remote work policies. Employee 1 mentions having read about these changes, and Employee 2 confirms that there will be a reduction in the number of days employees can work from home. Employee 3 expresses disappointment, as they enjoyed the convenience of working from home. Employee 4 agrees with the preference for remote work but understands the need for more in-office presence to enhance teamwork.'),
#  Document(metadata={'doc_id': 'a20b2573-7872-4611-8bc5-7f927e034d6c'}, page_content="In una conversazione tra impiegati, uno di loro suggerisce che con più pause caffè insieme ci si possa divertire di più. Un altro menziona la nuova macchina da caffè, lodando la qualità dell'espresso che produce, migliore rispetto alla precedente. Gli altri impiegati concordano, esprimendo la loro soddisfazione per la macchina, considerandola un aspetto positivo in una settimana altrimenti difficile."),
#  Document(metadata={'doc_id': '7117b443-1d10-4b51-a03b-bd4aa2e90a24'}, page_content='In un incontro tra quattro impiegati, si discute dei progetti in corso. Il primo impiegato si sente sopraffatto dal lavoro. Il secondo riferisce che il suo progetto sta andando bene, ma presenta complicazioni improvvise. Il terzo sta preparando una presentazione per i clienti, che è quasi completa, ma richiede ancora alcune rifiniture. Infine, il quarto impiegato è impegnato a rispettare scadenze, definendo la situazione come una corsa contro il tempo.'),
#  Document(metadata={'doc_id': 'fe070abf-33e0-4bd8-b77a-b20e53faa6e3'}, page_content="Quattro impiegati discutono del lavoro e della frenesia della giornata lavorativa. Riconoscono l'importanza del supporto reciproco tra colleghi e delle pause caffè come momento di ricarica e socializzazione. Alla fine della conversazione, uno di loro chiede se qualcuno ha piani per il weekend."),
#  Document(metadata={'doc_id': 'cb2c5206-a808-4c31-82e2-3cbb2031c31c'}, page_content="In una conversazione tra quattro impiegati, ciascuno condivide i propri piani per il weekend. Impiegato 1 prevede di andare al mare se il tempo è favorevole per rilassarsi. Impiegato 2 preferisce un'escursione in montagna per godere dell'aria aperta. Impiegato 3 intende visitare una nuova mostra d'arte in città. Infine, Impiegato 4 ha intenzione di rilassarsi a casa, magari guardando film o leggendo un libro."),
#  Document(metadata={'doc_id': '5763c625-47b2-48a0-975f-4b6177f4c577'}, page_content='In un breve scambio tra quattro impiegati, si parla di come sia importante prendersi delle pause e godersi il tempo libero. Dopo aver riconosciuto che è quasi ora di tornare al lavoro, si salutano con un promemoria di una prossima pausa caffè tra qualche ora. La conversazione è leggera e amichevole, riflettendo un ambiente di lavoro positivo.')]

# %%
retriever.vectorstore.add_documents(summary_docs)
retriever.docstore.mset(list(zip(doc_ids, docs))) # imposta il valore `docs` as ogni `docs_id`

# # Metodo alternativo:
# # possiamo aggiungere il doc_id ai chunk originali
# for i, doc in enumerate(summary_docs):
#     doc.metadata[id_key] = doc_ids[i]
# retriever.vectorstore.add_documents(summary_docs)

# %%
sub_docs = vectorstore.similarity_search("mamme che parlano")

sub_docs
# Out:
# [Document(id='91c504ad-289b-4a47-8256-9ed8eb5354f1', metadata={'doc_id': '49b206d4-d843-4bbb-a46b-2dc07182374e'}, page_content='In una conversazione tra mamme, Mamma 1 chiede come stanno andando a scuola i loro bambini. Mamma 2 condivide che Marco sta avendo difficoltà in matematica, ma stanno lavorando con un tutor. Mamma 3 dice che Laura ama la matematica, ma trova noiosa la storia. Mamma 4 menziona che anche Emma ha difficoltà con le date di storia, ma è brava in italiano. Infine, Mamma 1 nota che Pietro è bravo in tutte le materie, ma è molto disordinato e fatica a tenere in ordine il suo zaino e i quaderni.'),
#  Document(id='6888178f-9fc0-4255-ade2-c2994c7844e6', metadata={'doc_id': '09b781b2-4fe0-44c2-9cc0-81ac85399ecf'}, page_content="Le mamme discutono della nuova maestra di inglese, che sembra essere molto competente. Una mamma menziona l'entusiasmo della sua figlia per le lezioni stimolanti, mentre un'altra spera che la nuova maestra possa aiutare sua figlia Emma, che ha sempre trovato difficile l'inglese. Un'altra mamma condivide che suo figlio Pietro è felice dell'approccio didattico della maestra, che include giochi e attività divertenti."),
#  Document(id='9a61c095-62fc-4507-8332-89387fd3c3b6', metadata={'doc_id': 'afa0ffa3-c270-43fb-9508-0572b6c0de63'}, page_content='In una conversazione davanti alla scuola, alcune mamme si scambiano saluti e si lamentano della stanchezza accumulata dopo una settimana intensa tra lavoro e figli. Una di loro esprime il desiderio di avere una giornata solo per se stessa.'),
#  Document(id='35466b3b-e52b-43c6-9d31-d3564a606418', metadata={'doc_id': '998b0ed0-d753-48f6-a420-565a27cbbe6c'}, page_content='Le mamme discutono del nuovo laboratorio di scienze, esprimendo entusiasmo per i loro figli. Mamma 3 menziona che Laura è eccitata di partecipare, mentre Mamma 4 condivide che Emma sogna di diventare una scienziata. Mamma 1 commenta l’interesse di Pietro, ma spera che non causino troppo disordine durante le attività.')]

# %% [markdown]
# ## Query Ipotetiche

# %%
from pydantic import BaseModel
from typing import List
from langchain_core.runnables import RunnableLambda

class HypotheticalQuestions(BaseModel):
    """Generate hypothetical questions"""

    questions: List[str]

only_questions_parser = RunnableLambda(lambda x: x.questions)

chain = (
    {"doc": lambda x: x.page_content}
    | ChatPromptTemplate.from_template(
        "Generate a list of exactly 3 hypothetical questions that the below document could be used to answer:\n\n{doc}"
    )
    | ChatOpenAI(model="gpt-4o-mini", max_retries=3).with_structured_output(HypotheticalQuestions)
    | only_questions_parser
)

# %%
chain.invoke(docs[0])
# Out:
# ['What would happen if the customer wanted to try on a shirt instead of pants?',
#  "How would the interaction change if the customer didn't know their size?",
#  'What might the conversation look like if the customer wanted a different color or style of pants?']

# %%
hypothetical_questions = chain.batch(docs, {"max_concurrency": 15})

# %%
hypothetical_questions
# Out:
# [['What would happen if the customer asked for a different color of the pants?',
#   'How might the interaction change if the customer were looking for a shirt instead of pants?',
#   'What if the customer had a sizing question about the pants they tried on?'],
#  ['What would happen if the heat lasted for a whole week without any rain?',
#   "How might the customer's plans in the city change if it rains again unexpectedly later in the day?",
#   'What could be done to prepare for sudden summer storms like the one experienced by the customer?'],
#  ['What if the Lakers had won the game instead of the Celtics?',
#   'How would the conversation change if they were discussing a different sport, like soccer?',
#   'What might have been the outcome if LeBron had performed at his usual level during the game?'],
#  ['What might happen if the game had gone into double overtime?',
#   'How would the conversation change if they were discussing a different sporting event instead?',
#   "What could have been the reason for the customer's tiredness after the event?"],
#  ['What would the cliente choose if they had to select a color for the pantaloni other than the available options?',
#   'How might the outcome change if the store had the desired size in black?',
#   'If the cliente had more time, what other items might they consider trying on alongside the pantaloni?'],
#  ['What could the customer have done if the pants were on sale?',
#   'How would the customer have reacted if the pants had been made of a different material?',
#   'What if the store did not accept credit cards as a payment option?'],
#  ['What might the customer do if it rains again tonight?',
#   "How would the customer's mood change if the Lakers lose the next game?",
#   'What alternative plans could the customer have if the weather prevents outdoor activities tonight?'],
#  ['What if Atleta 2 decides to increase their running time by 10 minutes instead of 5 each week?',
#   "How would Atleta 1's advice change if Atleta 2 was also training for a specific competition?",
#   'What if Atleta 2 has dietary restrictions that prevent them from consuming certain carbohydrates or proteins?'],
#  ['What dietary changes could be recommended for someone trying to increase muscle mass?',
#   'How might circuit training affect muscle endurance compared to traditional strength training?',
#   'What specific types of high-intensity exercises might be beneficial for an athlete focusing on resistance training?'],
#  ['What might be the benefits of following a split workout routine for muscle building?',
#   "How would consistency and patience impact an athlete's progress in strength training?",
#   "In what ways could discussing fitness goals with a peer influence an athlete's motivation and training approach?"],
#  ['What might Atleta 2 be experiencing in their training that prompted them to seek advice from Atleta 1?',
#   'How does Atleta 1 suggest maintaining a successful training regimen?',
#   'What could be the importance of patience and consistency in the context of athletic training?'],
#  ['What might happen if the mothers decided to take a day off for themselves?',
#   'How would the conversation change if one of the mothers had a particularly good week?',
#   'What could the mothers do together to alleviate their fatigue and stress?'],
#  ["What might happen if Marco doesn't improve in math despite the tutoring?",
#   "How could Laura's interest in math influence her approach to studying history?",
#   'What strategies might Pietro use to better organize his backpack and notebooks?'],
#  ['What would happen if the new English teacher implemented a unique teaching style that engaged students more effectively?',
#   "How might Emma's attitude towards learning English change if she continues to enjoy her lessons with the new teacher?",
#   'What could be the potential outcomes for students like Pietro if the new teacher focuses on fun activities and games during lessons?'],
#  ['What would happen if the meeting with the parents is postponed to a later date?',
#   'How might the parents contribute to the upcoming school projects discussed at the meeting?',
#   "What progress updates could be relevant for parents to discuss at the meeting regarding their children's development?"],
#  ['What might happen if the science lab features hands-on experiments?',
#   "How could participating in the science lab influence Laura's future aspirations?",
#   "What could be the potential challenges of having active experiments in the lab, based on Mamma 1's concerns about pasticci?"],
#  ['What alternative weekend plans could families consider if the weather is not favorable for outdoor activities?',
#   "How might the children's reactions differ when visiting their grandparents versus going to the park or the cinema?",
#   'What are some activities families could do together to engage children in nature aside from an excursion in the mountains?'],
#  ['How do working fathers balance their responsibilities with family time on weekends?',
#   'What strategies do mothers use to manage childcare when their husbands are busy with work?',
#   'In what ways can collaborative parenting impact the relationship dynamics between spouses?'],
#  ['What might happen tomorrow that the characters are excited about?',
#   'How do the characters feel about their upcoming departure?',
#   'What kind of event or gathering are the characters attending?'],
#  ["What if the customer couldn't find the whole wheat flour in the supermarket?",
#   'What if the second customer invited the first customer to join their dinner?',
#   'What if the first customer decided to change their dessert to a different recipe instead of the apple pie?'],
#  ["What if Cliente 1 decides to use organic apples in her grandmother's apple pie recipe?",
#   "How would Cliente 1 modify her grandmother's apple pie recipe to make it lighter while still using traditional ingredients?",
#   'What might Cliente 2 suggest if Cliente 1 expresses concerns about the sweetness of her apple pie with organic apples?'],
#  ['What if Cliente 1 decided to experiment with a recipe using both zucchine and spinaci in a single dish?',
#   'How would the conversation change if Cliente 2 preferred frozen vegetables instead of fresh ones?',
#   'What if Cliente 1 was unfamiliar with cooking and sought advice on how to prepare zucchine and spinaci?'],
#  ['What would happen if the clients decided not to buy the butter on sale?',
#   'How might the conversation change if one client had a dairy allergy?',
#   'What if the yogurt they both enjoy was out of stock, how would that affect their shopping plans?'],
#  ['What if Cliente 1 had decided to buy chicken instead of just accompanying Cliente 2?',
#   'What if Cliente 2 had suggested trying a different recipe for the chicken instead of chicken curry?',
#   'What if they encountered a sale on bread while at the bakery department and decided to buy more than planned?'],
#  ['What might Cliente 1 do if they walk into a bakery and smell fresh bread?',
#   'How would the interaction change if Cliente 2 decided to buy a different type of bread instead?',
#   "What could Cliente 1 have purchased if they weren't planning for a breakfast the next day?"],
#  ['What would happen if the customers encountered a long line at the checkout?',
#   'How might the shopping experience change if they were shopping alone instead of together?',
#   "What if one of the customers couldn't find an item they were looking for during the shopping trip?"],
#  ['What might happen if the employees continue to feel overwhelmed with their workload?',
#   'How would the team dynamics change if the boss implements stricter directives?',
#   'What strategies could the employees use to manage their stress during busy weeks?'],
#  ['What might the implications be for employees if remote work days are reduced?',
#   'How could the preference for working from home impact team dynamics if employees are required to return to the office more frequently?',
#   'What changes to workplace productivity might occur as a result of the shift towards more in-office work?'],
#  ['What if the new coffee machine had a malfunction that made the coffee taste bad?',
#   'How would the employees react if the coffee machine was removed from the break room altogether?',
#   'What if the employees had to start paying for coffee from the new machine?'],
#  ['What challenges might arise when completing a project on a tight deadline?',
#   'How can unexpected last-minute complications impact project timelines?',
#   'What strategies could employees use to manage their workload more effectively while working on multiple projects?'],
#  ['What if the employees decided to coordinate their coffee breaks to improve teamwork?',
#   'How would the office atmosphere change if employees did not take breaks during the workday?',
#   'What if one employee organized a team-building activity for the weekend?'],
#  ['What would happen if all employees decided to take a vacation at the same time?',
#   'How do the preferences for weekend activities reflect the personalities of the employees?',
#   'What might be the impact on team dynamics if employees frequently choose to relax in different environments over the weekends?'],
#  ['What would happen if all employees decided to take a longer break instead of returning to work?',
#   "How might the team's productivity change if they incorporated more frequent breaks throughout the day?",
#   'What are the potential benefits of having scheduled coffee breaks in the workplace?']]

# %%
vectorstore = Chroma(collection_name="hypo-questions", embedding_function=OpenAIEmbeddings())

store = InMemoryByteStore()
id_key = "doc_id"

retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    byte_store=store,
    id_key=id_key,
)

doc_ids = [str(uuid.uuid4()) for _ in docs]

# %%
question_docs = []
for i, question_list in enumerate(hypothetical_questions):
    question_docs.extend(
        [Document(page_content=s, metadata={id_key: doc_ids[i]}) for s in question_list]
    )

# %%
question_docs
# Out:
# [Document(metadata={'doc_id': '915d1cb2-86df-4a27-b92b-1263f58b3275'}, page_content='What would happen if the customer asked for a different color of the pants?'),
#  Document(metadata={'doc_id': '915d1cb2-86df-4a27-b92b-1263f58b3275'}, page_content='How might the interaction change if the customer were looking for a shirt instead of pants?'),
#  Document(metadata={'doc_id': '915d1cb2-86df-4a27-b92b-1263f58b3275'}, page_content='What if the customer had a sizing question about the pants they tried on?'),
#  Document(metadata={'doc_id': 'b8d052cd-2d90-4db7-b848-5e5b6942513c'}, page_content='What would happen if the heat lasted for a whole week without any rain?'),
#  Document(metadata={'doc_id': 'b8d052cd-2d90-4db7-b848-5e5b6942513c'}, page_content="How might the customer's plans in the city change if it rains again unexpectedly later in the day?"),
#  Document(metadata={'doc_id': 'b8d052cd-2d90-4db7-b848-5e5b6942513c'}, page_content='What could be done to prepare for sudden summer storms like the one experienced by the customer?'),
#  Document(metadata={'doc_id': '56074133-24bc-4cb2-bbae-76104e09054d'}, page_content='What if the Lakers had won the game instead of the Celtics?'),
#  Document(metadata={'doc_id': '56074133-24bc-4cb2-bbae-76104e09054d'}, page_content='How would the conversation change if they were discussing a different sport, like soccer?'),
#  Document(metadata={'doc_id': '56074133-24bc-4cb2-bbae-76104e09054d'}, page_content='What might have been the outcome if LeBron had performed at his usual level during the game?'),
#  Document(metadata={'doc_id': '473cac49-b25b-4ea1-8de3-083b91f677cd'}, page_content='What might happen if the game had gone into double overtime?'),
#  Document(metadata={'doc_id': '473cac49-b25b-4ea1-8de3-083b91f677cd'}, page_content='How would the conversation change if they were discussing a different sporting event instead?'),
#  Document(metadata={'doc_id': '473cac49-b25b-4ea1-8de3-083b91f677cd'}, page_content="What could have been the reason for the customer's tiredness after the event?"),
#  Document(metadata={'doc_id': '3452bc16-ffbf-4d51-924b-684fc88ba32c'}, page_content='What would the cliente choose if they had to select a color for the pantaloni other than the available options?'),
#  Document(metadata={'doc_id': '3452bc16-ffbf-4d51-924b-684fc88ba32c'}, page_content='How might the outcome change if the store had the desired size in black?'),
#  Document(metadata={'doc_id': '3452bc16-ffbf-4d51-924b-684fc88ba32c'}, page_content='If the cliente had more time, what other items might they consider trying on alongside the pantaloni?'),
#  Document(metadata={'doc_id': 'a54787d9-b5cc-424e-8de7-5bc39532fe30'}, page_content='What could the customer have done if the pants were on sale?'),
#  Document(metadata={'doc_id': 'a54787d9-b5cc-424e-8de7-5bc39532fe30'}, page_content='How would the customer have reacted if the pants had been made of a different material?'),
#  Document(metadata={'doc_id': 'a54787d9-b5cc-424e-8de7-5bc39532fe30'}, page_content='What if the store did not accept credit cards as a payment option?'),
#  Document(metadata={'doc_id': '6a67e549-afd8-4c66-a054-2e2a3fdc2dcc'}, page_content='What might the customer do if it rains again tonight?'),
#  Document(metadata={'doc_id': '6a67e549-afd8-4c66-a054-2e2a3fdc2dcc'}, page_content="How would the customer's mood change if the Lakers lose the next game?"),
#  Document(metadata={'doc_id': '6a67e549-afd8-4c66-a054-2e2a3fdc2dcc'}, page_content='What alternative plans could the customer have if the weather prevents outdoor activities tonight?'),
#  Document(metadata={'doc_id': '50d8a22b-1c09-4485-a208-5a051f504a09'}, page_content='What if Atleta 2 decides to increase their running time by 10 minutes instead of 5 each week?'),
#  Document(metadata={'doc_id': '50d8a22b-1c09-4485-a208-5a051f504a09'}, page_content="How would Atleta 1's advice change if Atleta 2 was also training for a specific competition?"),
#  Document(metadata={'doc_id': '50d8a22b-1c09-4485-a208-5a051f504a09'}, page_content='What if Atleta 2 has dietary restrictions that prevent them from consuming certain carbohydrates or proteins?'),
#  Document(metadata={'doc_id': '372c43f7-8e45-4ecb-a692-5e25d8234eac'}, page_content='What dietary changes could be recommended for someone trying to increase muscle mass?'),
#  Document(metadata={'doc_id': '372c43f7-8e45-4ecb-a692-5e25d8234eac'}, page_content='How might circuit training affect muscle endurance compared to traditional strength training?'),
#  Document(metadata={'doc_id': '372c43f7-8e45-4ecb-a692-5e25d8234eac'}, page_content='What specific types of high-intensity exercises might be beneficial for an athlete focusing on resistance training?'),
#  Document(metadata={'doc_id': '289c0c69-90b5-4e09-af89-e45ec01dbe7b'}, page_content='What might be the benefits of following a split workout routine for muscle building?'),
#  Document(metadata={'doc_id': '289c0c69-90b5-4e09-af89-e45ec01dbe7b'}, page_content="How would consistency and patience impact an athlete's progress in strength training?"),
#  Document(metadata={'doc_id': '289c0c69-90b5-4e09-af89-e45ec01dbe7b'}, page_content="In what ways could discussing fitness goals with a peer influence an athlete's motivation and training approach?"),
#  Document(metadata={'doc_id': '45802919-3703-46f4-8283-c4101cabf90e'}, page_content='What might Atleta 2 be experiencing in their training that prompted them to seek advice from Atleta 1?'),
#  Document(metadata={'doc_id': '45802919-3703-46f4-8283-c4101cabf90e'}, page_content='How does Atleta 1 suggest maintaining a successful training regimen?'),
#  Document(metadata={'doc_id': '45802919-3703-46f4-8283-c4101cabf90e'}, page_content='What could be the importance of patience and consistency in the context of athletic training?'),
#  Document(metadata={'doc_id': '3c3229c9-4649-49d2-b9f9-fae8b3da7213'}, page_content='What might happen if the mothers decided to take a day off for themselves?'),
#  Document(metadata={'doc_id': '3c3229c9-4649-49d2-b9f9-fae8b3da7213'}, page_content='How would the conversation change if one of the mothers had a particularly good week?'),
#  Document(metadata={'doc_id': '3c3229c9-4649-49d2-b9f9-fae8b3da7213'}, page_content='What could the mothers do together to alleviate their fatigue and stress?'),
#  Document(metadata={'doc_id': '519fc452-4b08-45bb-bb44-fdae5f57b662'}, page_content="What might happen if Marco doesn't improve in math despite the tutoring?"),
#  Document(metadata={'doc_id': '519fc452-4b08-45bb-bb44-fdae5f57b662'}, page_content="How could Laura's interest in math influence her approach to studying history?"),
#  Document(metadata={'doc_id': '519fc452-4b08-45bb-bb44-fdae5f57b662'}, page_content='What strategies might Pietro use to better organize his backpack and notebooks?'),
#  Document(metadata={'doc_id': '411681f8-1b30-4b45-bf40-bc9931bb936f'}, page_content='What would happen if the new English teacher implemented a unique teaching style that engaged students more effectively?'),
#  Document(metadata={'doc_id': '411681f8-1b30-4b45-bf40-bc9931bb936f'}, page_content="How might Emma's attitude towards learning English change if she continues to enjoy her lessons with the new teacher?"),
#  Document(metadata={'doc_id': '411681f8-1b30-4b45-bf40-bc9931bb936f'}, page_content='What could be the potential outcomes for students like Pietro if the new teacher focuses on fun activities and games during lessons?'),
#  Document(metadata={'doc_id': '7f8f1c32-c9f1-4f8e-a521-e0948a6a5c6d'}, page_content='What would happen if the meeting with the parents is postponed to a later date?'),
#  Document(metadata={'doc_id': '7f8f1c32-c9f1-4f8e-a521-e0948a6a5c6d'}, page_content='How might the parents contribute to the upcoming school projects discussed at the meeting?'),
#  Document(metadata={'doc_id': '7f8f1c32-c9f1-4f8e-a521-e0948a6a5c6d'}, page_content="What progress updates could be relevant for parents to discuss at the meeting regarding their children's development?"),
#  Document(metadata={'doc_id': '982a05c1-a7c0-4605-834b-8239d6d33238'}, page_content='What might happen if the science lab features hands-on experiments?'),
#  Document(metadata={'doc_id': '982a05c1-a7c0-4605-834b-8239d6d33238'}, page_content="How could participating in the science lab influence Laura's future aspirations?"),
#  Document(metadata={'doc_id': '982a05c1-a7c0-4605-834b-8239d6d33238'}, page_content="What could be the potential challenges of having active experiments in the lab, based on Mamma 1's concerns about pasticci?"),
#  Document(metadata={'doc_id': '7c877f1a-1c59-408b-8d89-129b61f0f5b4'}, page_content='What alternative weekend plans could families consider if the weather is not favorable for outdoor activities?'),
#  Document(metadata={'doc_id': '7c877f1a-1c59-408b-8d89-129b61f0f5b4'}, page_content="How might the children's reactions differ when visiting their grandparents versus going to the park or the cinema?"),
#  Document(metadata={'doc_id': '7c877f1a-1c59-408b-8d89-129b61f0f5b4'}, page_content='What are some activities families could do together to engage children in nature aside from an excursion in the mountains?'),
#  Document(metadata={'doc_id': '96d599b4-4ce8-4c51-bee3-131b196a46ef'}, page_content='How do working fathers balance their responsibilities with family time on weekends?'),
#  Document(metadata={'doc_id': '96d599b4-4ce8-4c51-bee3-131b196a46ef'}, page_content='What strategies do mothers use to manage childcare when their husbands are busy with work?'),
#  Document(metadata={'doc_id': '96d599b4-4ce8-4c51-bee3-131b196a46ef'}, page_content='In what ways can collaborative parenting impact the relationship dynamics between spouses?'),
#  Document(metadata={'doc_id': 'a8a5f77a-748d-40ac-9753-0a73a42d0c06'}, page_content='What might happen tomorrow that the characters are excited about?'),
#  Document(metadata={'doc_id': 'a8a5f77a-748d-40ac-9753-0a73a42d0c06'}, page_content='How do the characters feel about their upcoming departure?'),
#  Document(metadata={'doc_id': 'a8a5f77a-748d-40ac-9753-0a73a42d0c06'}, page_content='What kind of event or gathering are the characters attending?'),
#  Document(metadata={'doc_id': '31bfd0fb-5919-413b-be45-58d9c409c583'}, page_content="What if the customer couldn't find the whole wheat flour in the supermarket?"),
#  Document(metadata={'doc_id': '31bfd0fb-5919-413b-be45-58d9c409c583'}, page_content='What if the second customer invited the first customer to join their dinner?'),
#  Document(metadata={'doc_id': '31bfd0fb-5919-413b-be45-58d9c409c583'}, page_content='What if the first customer decided to change their dessert to a different recipe instead of the apple pie?'),
#  Document(metadata={'doc_id': 'abf66cdf-2a9a-490f-a378-00e7187a130a'}, page_content="What if Cliente 1 decides to use organic apples in her grandmother's apple pie recipe?"),
#  Document(metadata={'doc_id': 'abf66cdf-2a9a-490f-a378-00e7187a130a'}, page_content="How would Cliente 1 modify her grandmother's apple pie recipe to make it lighter while still using traditional ingredients?"),
#  Document(metadata={'doc_id': 'abf66cdf-2a9a-490f-a378-00e7187a130a'}, page_content='What might Cliente 2 suggest if Cliente 1 expresses concerns about the sweetness of her apple pie with organic apples?'),
#  Document(metadata={'doc_id': '738819e5-10e3-4942-b480-bb681620a0fe'}, page_content='What if Cliente 1 decided to experiment with a recipe using both zucchine and spinaci in a single dish?'),
#  Document(metadata={'doc_id': '738819e5-10e3-4942-b480-bb681620a0fe'}, page_content='How would the conversation change if Cliente 2 preferred frozen vegetables instead of fresh ones?'),
#  Document(metadata={'doc_id': '738819e5-10e3-4942-b480-bb681620a0fe'}, page_content='What if Cliente 1 was unfamiliar with cooking and sought advice on how to prepare zucchine and spinaci?'),
#  Document(metadata={'doc_id': '5d207d21-1d1a-4027-ba96-6443dd039936'}, page_content='What would happen if the clients decided not to buy the butter on sale?'),
#  Document(metadata={'doc_id': '5d207d21-1d1a-4027-ba96-6443dd039936'}, page_content='How might the conversation change if one client had a dairy allergy?'),
#  Document(metadata={'doc_id': '5d207d21-1d1a-4027-ba96-6443dd039936'}, page_content='What if the yogurt they both enjoy was out of stock, how would that affect their shopping plans?'),
#  Document(metadata={'doc_id': '10fb25af-00c5-4020-a865-895567f60d01'}, page_content='What if Cliente 1 had decided to buy chicken instead of just accompanying Cliente 2?'),
#  Document(metadata={'doc_id': '10fb25af-00c5-4020-a865-895567f60d01'}, page_content='What if Cliente 2 had suggested trying a different recipe for the chicken instead of chicken curry?'),
#  Document(metadata={'doc_id': '10fb25af-00c5-4020-a865-895567f60d01'}, page_content='What if they encountered a sale on bread while at the bakery department and decided to buy more than planned?'),
#  Document(metadata={'doc_id': '882bb220-50ac-47d0-903c-8b5221037770'}, page_content='What might Cliente 1 do if they walk into a bakery and smell fresh bread?'),
#  Document(metadata={'doc_id': '882bb220-50ac-47d0-903c-8b5221037770'}, page_content='How would the interaction change if Cliente 2 decided to buy a different type of bread instead?'),
#  Document(metadata={'doc_id': '882bb220-50ac-47d0-903c-8b5221037770'}, page_content="What could Cliente 1 have purchased if they weren't planning for a breakfast the next day?"),
#  Document(metadata={'doc_id': '0f333d28-9108-4bab-886b-90731a648d7f'}, page_content='What would happen if the customers encountered a long line at the checkout?'),
#  Document(metadata={'doc_id': '0f333d28-9108-4bab-886b-90731a648d7f'}, page_content='How might the shopping experience change if they were shopping alone instead of together?'),
#  Document(metadata={'doc_id': '0f333d28-9108-4bab-886b-90731a648d7f'}, page_content="What if one of the customers couldn't find an item they were looking for during the shopping trip?"),
#  Document(metadata={'doc_id': '7a439627-34ba-4035-80b1-0666243471e7'}, page_content='What might happen if the employees continue to feel overwhelmed with their workload?'),
#  Document(metadata={'doc_id': '7a439627-34ba-4035-80b1-0666243471e7'}, page_content='How would the team dynamics change if the boss implements stricter directives?'),
#  Document(metadata={'doc_id': '7a439627-34ba-4035-80b1-0666243471e7'}, page_content='What strategies could the employees use to manage their stress during busy weeks?'),
#  Document(metadata={'doc_id': 'cd478961-89f2-4549-98b6-c559e1f87037'}, page_content='What might the implications be for employees if remote work days are reduced?'),
#  Document(metadata={'doc_id': 'cd478961-89f2-4549-98b6-c559e1f87037'}, page_content='How could the preference for working from home impact team dynamics if employees are required to return to the office more frequently?'),
#  Document(metadata={'doc_id': 'cd478961-89f2-4549-98b6-c559e1f87037'}, page_content='What changes to workplace productivity might occur as a result of the shift towards more in-office work?'),
#  Document(metadata={'doc_id': 'b15c1179-0935-4848-a373-4176a66d4a70'}, page_content='What if the new coffee machine had a malfunction that made the coffee taste bad?'),
#  Document(metadata={'doc_id': 'b15c1179-0935-4848-a373-4176a66d4a70'}, page_content='How would the employees react if the coffee machine was removed from the break room altogether?'),
#  Document(metadata={'doc_id': 'b15c1179-0935-4848-a373-4176a66d4a70'}, page_content='What if the employees had to start paying for coffee from the new machine?'),
#  Document(metadata={'doc_id': '81c4249b-8e30-4313-90a5-73a9a674cf33'}, page_content='What challenges might arise when completing a project on a tight deadline?'),
#  Document(metadata={'doc_id': '81c4249b-8e30-4313-90a5-73a9a674cf33'}, page_content='How can unexpected last-minute complications impact project timelines?'),
#  Document(metadata={'doc_id': '81c4249b-8e30-4313-90a5-73a9a674cf33'}, page_content='What strategies could employees use to manage their workload more effectively while working on multiple projects?'),
#  Document(metadata={'doc_id': '5114c360-8e18-47fd-8ecf-894ee7d65a3c'}, page_content='What if the employees decided to coordinate their coffee breaks to improve teamwork?'),
#  Document(metadata={'doc_id': '5114c360-8e18-47fd-8ecf-894ee7d65a3c'}, page_content='How would the office atmosphere change if employees did not take breaks during the workday?'),
#  Document(metadata={'doc_id': '5114c360-8e18-47fd-8ecf-894ee7d65a3c'}, page_content='What if one employee organized a team-building activity for the weekend?'),
#  Document(metadata={'doc_id': '53dc74f4-a1a1-47ac-8c7f-f32bfdb4faca'}, page_content='What would happen if all employees decided to take a vacation at the same time?'),
#  Document(metadata={'doc_id': '53dc74f4-a1a1-47ac-8c7f-f32bfdb4faca'}, page_content='How do the preferences for weekend activities reflect the personalities of the employees?'),
#  Document(metadata={'doc_id': '53dc74f4-a1a1-47ac-8c7f-f32bfdb4faca'}, page_content='What might be the impact on team dynamics if employees frequently choose to relax in different environments over the weekends?'),
#  Document(metadata={'doc_id': '5198e6ab-64b8-468f-88f0-0de5f01002ad'}, page_content='What would happen if all employees decided to take a longer break instead of returning to work?'),
#  Document(metadata={'doc_id': '5198e6ab-64b8-468f-88f0-0de5f01002ad'}, page_content="How might the team's productivity change if they incorporated more frequent breaks throughout the day?"),
#  Document(metadata={'doc_id': '5198e6ab-64b8-468f-88f0-0de5f01002ad'}, page_content='What are the potential benefits of having scheduled coffee breaks in the workplace?')]

# %%
retriever.vectorstore.add_documents(question_docs)
retriever.docstore.mset(list(zip(doc_ids, docs)))

# %%
sub_docs = vectorstore.similarity_search("mamme che parlano")

# %%
sub_docs
# Out:
# [Document(id='5a765e58-8fba-4c73-a5ec-fb3815a52f63', metadata={'doc_id': '3c3229c9-4649-49d2-b9f9-fae8b3da7213'}, page_content='How would the conversation change if one of the mothers had a particularly good week?'),
#  Document(id='9b01993c-7689-42c4-9ecb-f604a8438031', metadata={'doc_id': '3c3229c9-4649-49d2-b9f9-fae8b3da7213'}, page_content='What could the mothers do together to alleviate their fatigue and stress?'),
#  Document(id='9b456155-1d87-4487-b532-fd3024052de0', metadata={'doc_id': '96d599b4-4ce8-4c51-bee3-131b196a46ef'}, page_content='What strategies do mothers use to manage childcare when their husbands are busy with work?'),
#  Document(id='079e358b-f0a5-46a6-971e-b46da69ff241', metadata={'doc_id': '3c3229c9-4649-49d2-b9f9-fae8b3da7213'}, page_content='What might happen if the mothers decided to take a day off for themselves?')]

# %%
retrieved_docs = retriever.invoke("mamme che parlano")

# %%
for retr in retrieved_docs:
    print(retr, "\n")
# Out:
# page_content='Davanti alla scuola
# Mamma 1 - Ciao ragazze! Come state oggi?
# Mamma 2 - Ciao! Bene, grazie. Solo un po' stanca, Ã¨ stata una settimana lunga. E voi?
# Mamma 3 - Anche io sono un po' stanca. Tra lavoro e figli, non ho un attimo di pausa!
# Mamma 4 - Vi capisco perfettamente. Ogni tanto vorrei una giornata solo per me.' metadata={'source': 'data/dialoghi/dialogo3.txt'}
#
# page_content='Mamma 3 - E i vostri mariti? Come si stanno organizzando con i bambini?
# Mamma 4 - Mio marito Ã¨ molto impegnato con il lavoro, ma cerchiamo di trovare sempre del tempo da passare insieme nel fine settimana.
# Mamma 1 - Il mio cerca di aiutare il piÃ¹ possibile, anche se a volte sembra piÃ¹ un altro bambino da gestire!
# Mamma 2 - Il mio Ã¨ molto coinvolto. Si occupa spesso dei compiti dei bambini, soprattutto in materie che io non capisco!
# Mamma 3 - Il mio Ã¨ simile. Fa il possibile per essere presente. Siamo fortunate ad avere mariti collaborativi.' metadata={'source': 'data/dialoghi/dialogo3.txt'}
